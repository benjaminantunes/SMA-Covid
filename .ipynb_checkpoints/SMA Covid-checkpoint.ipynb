# %%
# !make
# Out:
# g++ -o main.o -c main.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o World.o -c World.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o SimulationParams.o -c SimulationParams.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -O2 main.o Human.o City.o RandMT.o Position.o World.o SimulationParams.o  -o exe

# %%
## A CHANGER EN FONCTION DE LA CONFIG QUE VOUS VOULEZ TESTER

# %%
# !./replicationSimulationFrance.sh 4 configVaccin
# Out:
# 96
# 191
# 286
# 381
# Nom de la commande :./exe
# Nom du fichier MT a utiliser avec un nombre :1
# Nom du fichier de config :configVaccin
# Nom de la commande :./exe
# Nom du fichier MT a utiliser avec un nombre :96
# Nom du fichier de config :configVaccin
# Nom de la commande :./exe
# Nom de la commande :./exe
# Nom du fichier MT a utiliser avec un nombre :286
# Nom du fichier MT a utiliser avec un nombre :191
# Nom du fichier de config :configVaccin
# Nom du fichier de config :configVaccin
# log file name : log-configDpt01-MT-0001configVaccinNumRepli1.txt
# log file name : log-configDpt01-MT-0096configVaccinNumRepli2.txt
# log file name : log-configDpt01-MT-0191configVaccinNumRepli3.txt
# log file name : log-configDpt01-MT-0286configVaccinNumRepli4.txt
# La ville a pour coord X : 4898 , coordY : 0, taille : 4898 , nbHab : 41111
# La ville a pour coord X : 10898 , coordY : 0, taille : 6000 , nbHab : 22456
# La ville a pour coord X : 18835 , coordY : 0, taille : 7937 , nbHab : 16378
# La ville a pour coord X : 23835 , coordY : 0, taille : 5000 , nbHab : 14134
# La ville a pour coord X : 29491 , coordY : 0, taille : 5656 , nbHab : 13121
# La ville a pour coord X : 32653 , coordY : 0, taille : 3162 , nbHab : 13943
# La ville a pour coord X : 37551 , coordY : 0, taille : 4898 , nbHab : 10122
# La ville a pour coord X : 39787 , coordY : 0, taille : 2236 , nbHab : 10026
# La ville a pour coord X : 45617 , coordY : 0, taille : 5830 , nbHab : 9951
# La ville a pour coord X : 50307 , coordY : 0, taille : 4690 , nbHab : 9182
# La ville a pour coord X : 53771 , coordY : 0, taille : 3464 , nbHab : 8711
# La ville a pour coord X : 57512 , coordY : 0, taille : 3741 , nbHab : 7923
# La ville a pour coord X : 63836 , coordY : 0, taille : 6324 , nbHab : 6886
# La ville a pour coord X : 69032 , coordY : 0, taille : 5196 , nbHab : 7161
# La ville a pour coord X : 71481 , coordY : 0, taille : 2449 , nbHab : 6920
# La ville a pour coord X : 4898 , coordY : 0, taille : 4898 , nbHab : 41111
# La ville a pour coord X : 10898 , coordY : 0, taille : 6000 , nbHab : 22456
# La ville a pour coord X : 18835 , coordY : 0, taille : 7937 , nbHab : 16378
# La ville a pour coord X : 23835 , coordY : 0, taille : 5000 , nbHab : 14134
# La ville a pour coord X : 29491 , coordY : 0, taille : 5656 , nbHab : 13121
# La ville a pour coord X : 32653 , coordY : 0, taille : 3162 , nbHab : 13943
# La ville a pour coord X : 37551 , coordY : 0, taille : 4898 , nbHab : 10122
# La ville a pour coord X : 39787 , coordY : 0, taille : 2236 , nbHab : 10026
# La ville a pour coord X : 45617 , coordY : 0, taille : 5830 , nbHab : 9951
# La ville a pour coord X : 50307 , coordY : 0, taille : 4690 , nbHab : 9182
# La ville a pour coord X : 53771 , coordY : 0, taille : 3464 , nbHab : 8711
# La ville a pour coord X : 57512 , coordY : 0, taille : 3741 , nbHab : 7923
# La ville a pour coord X : 63836 , coordY : 0, taille : 6324 , nbHab : 6886
# La ville a pour coord X : 69032 , coordY : 0, taille : 5196 , nbHab : 7161
# La ville a pour coord X : 71481 , coordY : 0, taille : 2449 , nbHab : 6920
# La ville a pour coord X : 4898 , coordY : 0, taille : 4898 , nbHab : 41111
# La ville a pour coord X : 10898 , coordY : 0, taille : 6000 , nbHab : 22456
# La ville a pour coord X : 18835 , coordY : 0, taille : 7937 , nbHab : 16378
# La ville a pour coord X : 23835 , coordY : 0, taille : 5000 , nbHab : 14134
# La ville a pour coord X : 29491 , coordY : 0, taille : 5656 , nbHab : 13121
# La ville a pour coord X : 32653 , coordY : 0, taille : 3162 , nbHab : 13943
# La ville a pour coord X : 37551 , coordY : 0, taille : 4898 , nbHab : 10122
# La ville a pour coord X : 39787 , coordY : 0, taille : 2236 , nbHab : 10026
# La ville a pour coord X : 45617 , coordY : 0, taille : 5830 , nbHab : 9951
# La ville a pour coord X : 50307 , coordY : 0, taille : 4690 , nbHab : 9182
# La ville a pour coord X : 53771 , coordY : 0, taille : 3464 , nbHab : 8711
# La ville a pour coord X : 57512 , coordY : 0, taille : 3741 , nbHab : 7923
# La ville a pour coord X : 63836 , coordY : 0, taille : 6324 , nbHab : 6886
# La ville a pour coord X : 4898 , coordY : 0, taille : 4898 , nbHab : 41111
# La ville a pour coord X : 69032 , coordY : 0, taille : 5196 , nbHab : 7161
# La ville a pour coord X : 71481 , coordY : 0, taille : 2449 , nbHab : 6920
# La ville a pour coord X : 10898 , coordY : 0, taille : 6000 , nbHab : 22456
# La ville a pour coord X : 18835 , coordY : 0, taille : 7937 , nbHab : 16378
# La ville a pour coord X : 23835 , coordY : 0, taille : 5000 , nbHab : 14134
# La ville a pour coord X : 29491 , coordY : 0, taille : 5656 , nbHab : 13121
# La ville a pour coord X : 32653 , coordY : 0, taille : 3162 , nbHab : 13943
# La ville a pour coord X : 37551 , coordY : 0, taille : 4898 , nbHab : 10122
# La ville a pour coord X : 39787 , coordY : 0, taille : 2236 , nbHab : 10026
# La ville a pour coord X : 45617 , coordY : 0, taille : 5830 , nbHab : 9951
# La ville a pour coord X : 50307 , coordY : 0, taille : 4690 , nbHab : 9182
# La ville a pour coord X : 53771 , coordY : 0, taille : 3464 , nbHab : 8711
# La ville a pour coord X : 57512 , coordY : 0, taille : 3741 , nbHab : 7923
# La ville a pour coord X : 63836 , coordY : 0, taille : 6324 , nbHab : 6886
# La ville a pour coord X : 69032 , coordY : 0, taille : 5196 , nbHab : 7161
# La ville a pour coord X : 71481 , coordY : 0, taille : 2449 , nbHab : 6920
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 649775
# Contamined : 0
# Recovered : 1648
# Dead : 19
# log file name : log-configDpt02-MT-0192configVaccinNumRepli3.txt
# La ville a pour coord X : 4795 , coordY : 0, taille : 4795 , nbHab : 53570
# La ville a pour coord X : 8259 , coordY : 0, taille : 3464 , nbHab : 28712
# La ville a pour coord X : 14739 , coordY : 0, taille : 6480 , nbHab : 24304
# La ville a pour coord X : 18862 , coordY : 0, taille : 4123 , nbHab : 15254
# La ville a pour coord X : 23104 , coordY : 0, taille : 4242 , nbHab : 13588
# La ville a pour coord X : 26709 , coordY : 0, taille : 3605 , nbHab : 11653
# La ville a pour coord X : 33189 , coordY : 0, taille : 6480 , nbHab : 10424
# La ville a pour coord X : 39019 , coordY : 0, taille : 5830 , nbHab : 8710
# La ville a pour coord X : 44675 , coordY : 0, taille : 5656 , nbHab : 5686
# La ville a pour coord X : 47124 , coordY : 0, taille : 2449 , nbHab : 5235
# La ville a pour coord X : 51124 , coordY : 0, taille : 4000 , nbHab : 4645
# La ville a pour coord X : 53360 , coordY : 0, taille : 2236 , nbHab : 3832
# La ville a pour coord X : 59840 , coordY : 0, taille : 6480 , nbHab : 3314
# La ville a pour coord X : 64312 , coordY : 0, taille : 4472 , nbHab : 3001
# La ville a pour coord X : 68184 , coordY : 0, taille : 3872 , nbHab : 2958
# Le pourcentage de carte recouverte par des lieu est de : -0.000000 %
# ***************STATISTICS******************
# Safe : 649784
# Contamined : 0
# Recovered : 1628
# Dead : 30
# ***************STATISTICS******************
# Safe : 649601
# Contamined : 0
# Recovered : 1821
# Dead : 20
# log file name : log-configDpt02-MT-0287configVaccinNumRepli4.txt
# log file name : log-configDpt02-MT-0097configVaccinNumRepli2.txt
# ***************STATISTICS******************
# Safe : 649810
# Contamined : 0
# Recovered : 1612
# Dead : 20
# log file name : log-configDpt02-MT-0002configVaccinNumRepli1.txt
# La ville a pour coord X : 4795 , coordY : 0, taille : 4795 , nbHab : 53570
# La ville a pour coord X : 8259 , coordY : 0, taille : 3464 , nbHab : 28712
# La ville a pour coord X : 14739 , coordY : 0, taille : 6480 , nbHab : 24304
# La ville a pour coord X : 18862 , coordY : 0, taille : 4123 , nbHab : 15254
# La ville a pour coord X : 23104 , coordY : 0, taille : 4242 , nbHab : 13588
# La ville a pour coord X : 26709 , coordY : 0, taille : 3605 , nbHab : 11653
# La ville a pour coord X : 33189 , coordY : 0, taille : 6480 , nbHab : 10424
# La ville a pour coord X : 39019 , coordY : 0, taille : 5830 , nbHab : 8710
# La ville a pour coord X : 44675 , coordY : 0, taille : 5656 , nbHab : 5686
# La ville a pour coord X : 47124 , coordY : 0, taille : 2449 , nbHab : 5235
# La ville a pour coord X : 51124 , coordY : 0, taille : 4000 , nbHab : 4645
# La ville a pour coord X : 53360 , coordY : 0, taille : 2236 , nbHab : 3832
# La ville a pour coord X : 59840 , coordY : 0, taille : 6480 , nbHab : 3314
# La ville a pour coord X : 64312 , coordY : 0, taille : 4472 , nbHab : 3001
# La ville a pour coord X : 68184 , coordY : 0, taille : 3872 , nbHab : 2958
# La ville a pour coord X : 4795 , coordY : 0, taille : 4795 , nbHab : 53570
# La ville a pour coord X : 8259 , coordY : 0, taille : 3464 , nbHab : 28712
# La ville a pour coord X : 14739 , coordY : 0, taille : 6480 , nbHab : 24304
# La ville a pour coord X : 18862 , coordY : 0, taille : 4123 , nbHab : 15254
# La ville a pour coord X : 23104 , coordY : 0, taille : 4242 , nbHab : 13588
# La ville a pour coord X : 26709 , coordY : 0, taille : 3605 , nbHab : 11653
# La ville a pour coord X : 33189 , coordY : 0, taille : 6480 , nbHab : 10424
# La ville a pour coord X : 39019 , coordY : 0, taille : 5830 , nbHab : 8710
# La ville a pour coord X : 44675 , coordY : 0, taille : 5656 , nbHab : 5686
# La ville a pour coord X : 47124 , coordY : 0, taille : 2449 , nbHab : 5235
# La ville a pour coord X : 51124 , coordY : 0, taille : 4000 , nbHab : 4645
# La ville a pour coord X : 53360 , coordY : 0, taille : 2236 , nbHab : 3832
# La ville a pour coord X : 59840 , coordY : 0, taille : 6480 , nbHab : 3314
# La ville a pour coord X : 64312 , coordY : 0, taille : 4472 , nbHab : 3001
# La ville a pour coord X : 68184 , coordY : 0, taille : 3872 , nbHab : 2958
# Le pourcentage de carte recouverte par des lieu est de : -0.000000 %
# Le pourcentage de carte recouverte par des lieu est de : -0.000000 %
# La ville a pour coord X : 4795 , coordY : 0, taille : 4795 , nbHab : 53570
# La ville a pour coord X : 8259 , coordY : 0, taille : 3464 , nbHab : 28712
# La ville a pour coord X : 14739 , coordY : 0, taille : 6480 , nbHab : 24304
# La ville a pour coord X : 18862 , coordY : 0, taille : 4123 , nbHab : 15254
# La ville a pour coord X : 23104 , coordY : 0, taille : 4242 , nbHab : 13588
# La ville a pour coord X : 26709 , coordY : 0, taille : 3605 , nbHab : 11653
# La ville a pour coord X : 33189 , coordY : 0, taille : 6480 , nbHab : 10424
# La ville a pour coord X : 39019 , coordY : 0, taille : 5830 , nbHab : 8710
# La ville a pour coord X : 44675 , coordY : 0, taille : 5656 , nbHab : 5686
# La ville a pour coord X : 47124 , coordY : 0, taille : 2449 , nbHab : 5235
# La ville a pour coord X : 51124 , coordY : 0, taille : 4000 , nbHab : 4645
# La ville a pour coord X : 53360 , coordY : 0, taille : 2236 , nbHab : 3832
# La ville a pour coord X : 59840 , coordY : 0, taille : 6480 , nbHab : 3314
# La ville a pour coord X : 64312 , coordY : 0, taille : 4472 , nbHab : 3001
# La ville a pour coord X : 68184 , coordY : 0, taille : 3872 , nbHab : 2958
# Le pourcentage de carte recouverte par des lieu est de : -0.000000 %
# ***************STATISTICS******************
# Safe : 524019
# Contamined : 0
# Recovered : 6309
# Dead : 93
# log file name : log-configDpt03-MT-0193configVaccinNumRepli3.txt
# La ville a pour coord X : 4582 , coordY : 0, taille : 4582 , nbHab : 34361
# La ville a pour coord X : 7031 , coordY : 0, taille : 2449 , nbHab : 24980
# La ville a pour coord X : 10031 , coordY : 0, taille : 3000 , nbHab : 19246
# La ville a pour coord X : 16588 , coordY : 0, taille : 6557 , nbHab : 12838
# La ville a pour coord X : 22244 , coordY : 0, taille : 5656 , nbHab : 12474
# La ville a pour coord X : 28244 , coordY : 0, taille : 6000 , nbHab : 8729
# La ville a pour coord X : 32602 , coordY : 0, taille : 4358 , nbHab : 8741
# La ville a pour coord X : 37184 , coordY : 0, taille : 4582 , nbHab : 6132
# La ville a pour coord X : 43266 , coordY : 0, taille : 6082 , nbHab : 5830
# La ville a pour coord X : 49266 , coordY : 0, taille : 6000 , nbHab : 5221
# La ville a pour coord X : 52094 , coordY : 0, taille : 2828 , nbHab : 4459
# La ville a pour coord X : 56094 , coordY : 0, taille : 4000 , nbHab : 3953
# La ville a pour coord X : 58922 , coordY : 0, taille : 2828 , nbHab : 3654
# La ville a pour coord X : 63820 , coordY : 0, taille : 4898 , nbHab : 3618
# La ville a pour coord X : 67136 , coordY : 0, taille : 3316 , nbHab : 3297
# Le pourcentage de carte recouverte par des lieu est de : -0.000000 %
# ***************STATISTICS******************
# Safe : 524016
# Contamined : 0
# Recovered : 6315
# Dead : 90
# log file name : log-configDpt03-MT-0098configVaccinNumRepli2.txt
# ***************STATISTICS******************
# Safe : 526070
# Contamined : 0
# Recovered : 4283
# Dead : 68
# ***************STATISTICS******************
# Safe : 523912
# Contamined : 0
# Recovered : 6413
# Dead : 96
# log file name : log-configDpt03-MT-0288configVaccinNumRepli4.txt
# log file name : log-configDpt03-MT-0003configVaccinNumRepli1.txt
# La ville a pour coord X : 4582 , coordY : 0, taille : 4582 , nbHab : 34361
# La ville a pour coord X : 7031 , coordY : 0, taille : 2449 , nbHab : 24980
# La ville a pour coord X : 10031 , coordY : 0, taille : 3000 , nbHab : 19246
# La ville a pour coord X : 16588 , coordY : 0, taille : 6557 , nbHab : 12838
# La ville a pour coord X : 22244 , coordY : 0, taille : 5656 , nbHab : 12474
# La ville a pour coord X : 28244 , coordY : 0, taille : 6000 , nbHab : 8729
# La ville a pour coord X : 32602 , coordY : 0, taille : 4358 , nbHab : 8741
# La ville a pour coord X : 37184 , coordY : 0, taille : 4582 , nbHab : 6132
# La ville a pour coord X : 43266 , coordY : 0, taille : 6082 , nbHab : 5830
# La ville a pour coord X : 49266 , coordY : 0, taille : 6000 , nbHab : 5221
# La ville a pour coord X : 52094 , coordY : 0, taille : 2828 , nbHab : 4459
# La ville a pour coord X : 56094 , coordY : 0, taille : 4000 , nbHab : 3953
# La ville a pour coord X : 58922 , coordY : 0, taille : 2828 , nbHab : 3654
# La ville a pour coord X : 63820 , coordY : 0, taille : 4898 , nbHab : 3618
# La ville a pour coord X : 67136 , coordY : 0, taille : 3316 , nbHab : 3297
# Le pourcentage de carte recouverte par des lieu est de : -0.000000 %
# La ville a pour coord X : 4582 , coordY : 0, taille : 4582 , nbHab : 34361
# La ville a pour coord X : 7031 , coordY : 0, taille : 2449 , nbHab : 24980
# La ville a pour coord X : 10031 , coordY : 0, taille : 3000 , nbHab : 19246
# La ville a pour coord X : 16588 , coordY : 0, taille : 6557 , nbHab : 12838
# La ville a pour coord X : 22244 , coordY : 0, taille : 5656 , nbHab : 12474
# La ville a pour coord X : 28244 , coordY : 0, taille : 6000 , nbHab : 8729
# La ville a pour coord X : 32602 , coordY : 0, taille : 4358 , nbHab : 8741
# La ville a pour coord X : 37184 , coordY : 0, taille : 4582 , nbHab : 6132
# La ville a pour coord X : 43266 , coordY : 0, taille : 6082 , nbHab : 5830
# La ville a pour coord X : 49266 , coordY : 0, taille : 6000 , nbHab : 5221
# La ville a pour coord X : 52094 , coordY : 0, taille : 2828 , nbHab : 4459
# La ville a pour coord X : 56094 , coordY : 0, taille : 4000 , nbHab : 3953
# La ville a pour coord X : 58922 , coordY : 0, taille : 2828 , nbHab : 3654
# La ville a pour coord X : 63820 , coordY : 0, taille : 4898 , nbHab : 3618
# La ville a pour coord X : 67136 , coordY : 0, taille : 3316 , nbHab : 3297
# La ville a pour coord X : 4582 , coordY : 0, taille : 4582 , nbHab : 34361
# La ville a pour coord X : 7031 , coordY : 0, taille : 2449 , nbHab : 24980
# La ville a pour coord X : 10031 , coordY : 0, taille : 3000 , nbHab : 19246
# La ville a pour coord X : 16588 , coordY : 0, taille : 6557 , nbHab : 12838
# La ville a pour coord X : 22244 , coordY : 0, taille : 5656 , nbHab : 12474
# La ville a pour coord X : 28244 , coordY : 0, taille : 6000 , nbHab : 8729
# La ville a pour coord X : 32602 , coordY : 0, taille : 4358 , nbHab : 8741
# La ville a pour coord X : 37184 , coordY : 0, taille : 4582 , nbHab : 6132
# La ville a pour coord X : 43266 , coordY : 0, taille : 6082 , nbHab : 5830
# La ville a pour coord X : 49266 , coordY : 0, taille : 6000 , nbHab : 5221
# La ville a pour coord X : 52094 , coordY : 0, taille : 2828 , nbHab : 4459
# La ville a pour coord X : 56094 , coordY : 0, taille : 4000 , nbHab : 3953
# La ville a pour coord X : 58922 , coordY : 0, taille : 2828 , nbHab : 3654
# La ville a pour coord X : 63820 , coordY : 0, taille : 4898 , nbHab : 3618
# La ville a pour coord X : 67136 , coordY : 0, taille : 3316 , nbHab : 3297
# Le pourcentage de carte recouverte par des lieu est de : -0.000000 %
# Le pourcentage de carte recouverte par des lieu est de : -0.000000 %
# ***************STATISTICS******************
# Safe : 304621
# Contamined : 0
# Recovered : 29859
# Dead : 505
# log file name : log-configDpt04-MT-0194configVaccinNumRepli3.txt
# La ville a pour coord X : 7549 , coordY : 0, taille : 7549 , nbHab : 22528
# La ville a pour coord X : 18365 , coordY : 0, taille : 10816 , nbHab : 16482
# La ville a pour coord X : 25436 , coordY : 0, taille : 7071 , nbHab : 7595
# La ville a pour coord X : 31600 , coordY : 0, taille : 6164 , nbHab : 5867
# La ville a pour coord X : 35842 , coordY : 0, taille : 4242 , nbHab : 5089
# La ville a pour coord X : 42399 , coordY : 0, taille : 6557 , nbHab : 5121
# La ville a pour coord X : 47498 , coordY : 0, taille : 5099 , nbHab : 4323
# La ville a pour coord X : 55560 , coordY : 0, taille : 8062 , nbHab : 3751
# La ville a pour coord X : 60851 , coordY : 0, taille : 5291 , nbHab : 3905
# La ville a pour coord X : 64974 , coordY : 0, taille : 4123 , nbHab : 3442
# La ville a pour coord X : 76287 , coordY : 0, taille : 11313 , nbHab : 3173
# La ville a pour coord X : 80759 , coordY : 0, taille : 4472 , nbHab : 3206
# La ville a pour coord X : 0 , coordY : 11313, taille : 4795 , nbHab : 2813
# La ville a pour coord X : 8306 , coordY : 11313, taille : 8306 , nbHab : 2639
# La ville a pour coord X : 12306 , coordY : 11313, taille : 4000 , nbHab : 2564
# Le pourcentage de carte recouverte par des lieu est de : -0.000000 %
# ***************STATISTICS******************
# Safe : 304050
# Contamined : 0
# Recovered : 30390
# Dead : 545
# log file name : log-configDpt04-MT-0099configVaccinNumRepli2.txt
# ***************STATISTICS******************
# Safe : 304692
# Contamined : 0
# Recovered : 29779
# Dead : 514
# La ville a pour coord X : 7549 , coordY : 0, taille : 7549 , nbHab : 22528
# La ville a pour coord X : 18365 , coordY : 0, taille : 10816 , nbHab : 16482
# La ville a pour coord X : 25436 , coordY : 0, taille : 7071 , nbHab : 7595
# La ville a pour coord X : 31600 , coordY : 0, taille : 6164 , nbHab : 5867
# La ville a pour coord X : 35842 , coordY : 0, taille : 4242 , nbHab : 5089
# La ville a pour coord X : 42399 , coordY : 0, taille : 6557 , nbHab : 5121
# La ville a pour coord X : 47498 , coordY : 0, taille : 5099 , nbHab : 4323
# La ville a pour coord X : 55560 , coordY : 0, taille : 8062 , nbHab : 3751
# ***************STATISTICS******************
# Safe : 304724
# Contamined : 0
# Recovered : 29728
# Dead : 533
# La ville a pour coord X : 60851 , coordY : 0, taille : 5291 , nbHab : 3905
# La ville a pour coord X : 64974 , coordY : 0, taille : 4123 , nbHab : 3442
# La ville a pour coord X : 76287 , coordY : 0, taille : 11313 , nbHab : 3173
# La ville a pour coord X : 80759 , coordY : 0, taille : 4472 , nbHab : 3206
# La ville a pour coord X : 0 , coordY : 11313, taille : 4795 , nbHab : 2813
# La ville a pour coord X : 8306 , coordY : 11313, taille : 8306 , nbHab : 2639
# La ville a pour coord X : 12306 , coordY : 11313, taille : 4000 , nbHab : 2564
# log file name : log-configDpt04-MT-0004configVaccinNumRepli1.txt
# Le pourcentage de carte recouverte par des lieu est de : -0.000000 %
# log file name : log-configDpt04-MT-0289configVaccinNumRepli4.txt
# La ville a pour coord X : 7549 , coordY : 0, taille : 7549 , nbHab : 22528
# La ville a pour coord X : 18365 , coordY : 0, taille : 10816 , nbHab : 16482
# La ville a pour coord X : 25436 , coordY : 0, taille : 7071 , nbHab : 7595
# La ville a pour coord X : 31600 , coordY : 0, taille : 6164 , nbHab : 5867
# La ville a pour coord X : 35842 , coordY : 0, taille : 4242 , nbHab : 5089
# La ville a pour coord X : 42399 , coordY : 0, taille : 6557 , nbHab : 5121
# La ville a pour coord X : 47498 , coordY : 0, taille : 5099 , nbHab : 4323
# La ville a pour coord X : 55560 , coordY : 0, taille : 8062 , nbHab : 3751
# La ville a pour coord X : 60851 , coordY : 0, taille : 5291 , nbHab : 3905
# La ville a pour coord X : 64974 , coordY : 0, taille : 4123 , nbHab : 3442
# La ville a pour coord X : 76287 , coordY : 0, taille : 11313 , nbHab : 3173
# La ville a pour coord X : 80759 , coordY : 0, taille : 4472 , nbHab : 3206
# La ville a pour coord X : 0 , coordY : 11313, taille : 4795 , nbHab : 2813
# La ville a pour coord X : 8306 , coordY : 11313, taille : 8306 , nbHab : 2639
# La ville a pour coord X : 12306 , coordY : 11313, taille : 4000 , nbHab : 2564
# Le pourcentage de carte recouverte par des lieu est de : -0.000000 %
# La ville a pour coord X : 7549 , coordY : 0, taille : 7549 , nbHab : 22528
# La ville a pour coord X : 18365 , coordY : 0, taille : 10816 , nbHab : 16482
# La ville a pour coord X : 25436 , coordY : 0, taille : 7071 , nbHab : 7595
# La ville a pour coord X : 31600 , coordY : 0, taille : 6164 , nbHab : 5867
# La ville a pour coord X : 35842 , coordY : 0, taille : 4242 , nbHab : 5089
# La ville a pour coord X : 42399 , coordY : 0, taille : 6557 , nbHab : 5121
# La ville a pour coord X : 47498 , coordY : 0, taille : 5099 , nbHab : 4323
# La ville a pour coord X : 55560 , coordY : 0, taille : 8062 , nbHab : 3751
# La ville a pour coord X : 60851 , coordY : 0, taille : 5291 , nbHab : 3905
# La ville a pour coord X : 64974 , coordY : 0, taille : 4123 , nbHab : 3442
# La ville a pour coord X : 76287 , coordY : 0, taille : 11313 , nbHab : 3173
# La ville a pour coord X : 80759 , coordY : 0, taille : 4472 , nbHab : 3206
# La ville a pour coord X : 0 , coordY : 11313, taille : 4795 , nbHab : 2813
# La ville a pour coord X : 8306 , coordY : 11313, taille : 8306 , nbHab : 2639
# La ville a pour coord X : 12306 , coordY : 11313, taille : 4000 , nbHab : 2564
# Le pourcentage de carte recouverte par des lieu est de : -0.000000 %
# ***************STATISTICS******************
# Safe : 162238
# Contamined : 0
# Recovered : 1065
# Dead : 15
# log file name : log-configDpt05-MT-0195configVaccinNumRepli3.txt
# La ville a pour coord X : 10488 , coordY : 0, taille : 10488 , nbHab : 40631
# La ville a pour coord X : 15779 , coordY : 0, taille : 5291 , nbHab : 11339
# La ville a pour coord X : 21779 , coordY : 0, taille : 6000 , nbHab : 6335
# La ville a pour coord X : 26677 , coordY : 0, taille : 4898 , nbHab : 3543
# La ville a pour coord X : 33234 , coordY : 0, taille : 6557 , nbHab : 3216
# La ville a pour coord X : 40514 , coordY : 0, taille : 7280 , nbHab : 3061
# La ville a pour coord X : 45805 , coordY : 0, taille : 5291 , nbHab : 2562
# La ville a pour coord X : 53867 , coordY : 0, taille : 8062 , nbHab : 2255
# La ville a pour coord X : 61008 , coordY : 0, taille : 7141 , nbHab : 2312
# La ville a pour coord X : 64880 , coordY : 0, taille : 3872 , nbHab : 2285
# La ville a pour coord X : 70880 , coordY : 0, taille : 6000 , nbHab : 2063
# La ville a pour coord X : 0 , coordY : 10488, taille : 5099 , nbHab : 1531
# La ville a pour coord X : 2828 , coordY : 10488, taille : 2828 , nbHab : 1443
# La ville a pour coord X : 10176 , coordY : 10488, taille : 7348 , nbHab : 1528
# La ville a pour coord X : 16733 , coordY : 10488, taille : 6557 , nbHab : 1477
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 162260
# Contamined : 0
# Recovered : 1044
# Dead : 14
# log file name : log-configDpt05-MT-0100configVaccinNumRepli2.txt
# ***************STATISTICS******************
# Safe : 162250
# Contamined : 0
# Recovered : 1050
# Dead : 18
# La ville a pour coord X : 10488 , coordY : 0, taille : 10488 , nbHab : 40631
# La ville a pour coord X : 15779 , coordY : 0, taille : 5291 , nbHab : 11339
# La ville a pour coord X : 21779 , coordY : 0, taille : 6000 , nbHab : 6335
# La ville a pour coord X : 26677 , coordY : 0, taille : 4898 , nbHab : 3543
# La ville a pour coord X : 33234 , coordY : 0, taille : 6557 , nbHab : 3216
# La ville a pour coord X : 40514 , coordY : 0, taille : 7280 , nbHab : 3061
# La ville a pour coord X : 45805 , coordY : 0, taille : 5291 , nbHab : 2562
# La ville a pour coord X : 53867 , coordY : 0, taille : 8062 , nbHab : 2255
# La ville a pour coord X : 61008 , coordY : 0, taille : 7141 , nbHab : 2312
# La ville a pour coord X : 64880 , coordY : 0, taille : 3872 , nbHab : 2285
# La ville a pour coord X : 70880 , coordY : 0, taille : 6000 , nbHab : 2063
# La ville a pour coord X : 0 , coordY : 10488, taille : 5099 , nbHab : 1531
# La ville a pour coord X : 2828 , coordY : 10488, taille : 2828 , nbHab : 1443
# La ville a pour coord X : 10176 , coordY : 10488, taille : 7348 , nbHab : 1528
# La ville a pour coord X : 16733 , coordY : 10488, taille : 6557 , nbHab : 1477
# log file name : log-configDpt05-MT-0005configVaccinNumRepli1.txt
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 162265
# Contamined : 0
# Recovered : 1033
# Dead : 20
# La ville a pour coord X : 10488 , coordY : 0, taille : 10488 , nbHab : 40631
# La ville a pour coord X : 15779 , coordY : 0, taille : 5291 , nbHab : 11339
# La ville a pour coord X : 21779 , coordY : 0, taille : 6000 , nbHab : 6335
# La ville a pour coord X : 26677 , coordY : 0, taille : 4898 , nbHab : 3543
# La ville a pour coord X : 33234 , coordY : 0, taille : 6557 , nbHab : 3216
# La ville a pour coord X : 40514 , coordY : 0, taille : 7280 , nbHab : 3061
# La ville a pour coord X : 45805 , coordY : 0, taille : 5291 , nbHab : 2562
# La ville a pour coord X : 53867 , coordY : 0, taille : 8062 , nbHab : 2255
# La ville a pour coord X : 61008 , coordY : 0, taille : 7141 , nbHab : 2312
# La ville a pour coord X : 64880 , coordY : 0, taille : 3872 , nbHab : 2285
# La ville a pour coord X : 70880 , coordY : 0, taille : 6000 , nbHab : 2063
# La ville a pour coord X : 0 , coordY : 10488, taille : 5099 , nbHab : 1531
# La ville a pour coord X : 2828 , coordY : 10488, taille : 2828 , nbHab : 1443
# La ville a pour coord X : 10176 , coordY : 10488, taille : 7348 , nbHab : 1528
# La ville a pour coord X : 16733 , coordY : 10488, taille : 6557 , nbHab : 1477
# log file name : log-configDpt05-MT-0290configVaccinNumRepli4.txt
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# La ville a pour coord X : 10488 , coordY : 0, taille : 10488 , nbHab : 40631
# La ville a pour coord X : 15779 , coordY : 0, taille : 5291 , nbHab : 11339
# La ville a pour coord X : 21779 , coordY : 0, taille : 6000 , nbHab : 6335
# La ville a pour coord X : 26677 , coordY : 0, taille : 4898 , nbHab : 3543
# La ville a pour coord X : 33234 , coordY : 0, taille : 6557 , nbHab : 3216
# La ville a pour coord X : 40514 , coordY : 0, taille : 7280 , nbHab : 3061
# La ville a pour coord X : 45805 , coordY : 0, taille : 5291 , nbHab : 2562
# La ville a pour coord X : 53867 , coordY : 0, taille : 8062 , nbHab : 2255
# La ville a pour coord X : 61008 , coordY : 0, taille : 7141 , nbHab : 2312
# La ville a pour coord X : 64880 , coordY : 0, taille : 3872 , nbHab : 2285
# La ville a pour coord X : 70880 , coordY : 0, taille : 6000 , nbHab : 2063
# La ville a pour coord X : 0 , coordY : 10488, taille : 5099 , nbHab : 1531
# La ville a pour coord X : 2828 , coordY : 10488, taille : 2828 , nbHab : 1443
# La ville a pour coord X : 10176 , coordY : 10488, taille : 7348 , nbHab : 1528
# La ville a pour coord X : 16733 , coordY : 10488, taille : 6557 , nbHab : 1477
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 139179
# Contamined : 0
# Recovered : 1035
# Dead : 16
# log file name : log-configDpt06-MT-0196configVaccinNumRepli3.txt
# La ville a pour coord X : 8485 , coordY : 0, taille : 8485 , nbHab : 342669
# La ville a pour coord X : 13584 , coordY : 0, taille : 5099 , nbHab : 73438
# La ville a pour coord X : 18056 , coordY : 0, taille : 4472 , nbHab : 74545
# La ville a pour coord X : 24689 , coordY : 0, taille : 6633 , nbHab : 48870
# La ville a pour coord X : 28931 , coordY : 0, taille : 4242 , nbHab : 52178
# La ville a pour coord X : 31759 , coordY : 0, taille : 2828 , nbHab : 41887
# La ville a pour coord X : 34921 , coordY : 0, taille : 3162 , nbHab : 29169
# La ville a pour coord X : 38662 , coordY : 0, taille : 3741 , nbHab : 30525
# La ville a pour coord X : 42267 , coordY : 0, taille : 3605 , nbHab : 27364
# La ville a pour coord X : 47834 , coordY : 0, taille : 5567 , nbHab : 21998
# La ville a pour coord X : 52933 , coordY : 0, taille : 5099 , nbHab : 19982
# La ville a pour coord X : 59177 , coordY : 0, taille : 6244 , nbHab : 18940
# La ville a pour coord X : 63649 , coordY : 0, taille : 4472 , nbHab : 16285
# La ville a pour coord X : 65381 , coordY : 0, taille : 1732 , nbHab : 13358
# La ville a pour coord X : 0 , coordY : 8485, taille : 4358 , nbHab : 13486
# Le pourcentage de carte recouverte par des lieu est de : -nan %
# ***************STATISTICS******************
# Safe : 139160
# Contamined : 0
# Recovered : 1052
# Dead : 18
# log file name : log-configDpt06-MT-0101configVaccinNumRepli2.txt
# ***************STATISTICS******************
# Safe : 139186
# Contamined : 0
# Recovered : 1032
# Dead : 12
# La ville a pour coord X : 8485 , coordY : 0, taille : 8485 , nbHab : 342669
# La ville a pour coord X : 13584 , coordY : 0, taille : 5099 , nbHab : 73438
# La ville a pour coord X : 18056 , coordY : 0, taille : 4472 , nbHab : 74545
# La ville a pour coord X : 24689 , coordY : 0, taille : 6633 , nbHab : 48870
# La ville a pour coord X : 28931 , coordY : 0, taille : 4242 , nbHab : 52178
# La ville a pour coord X : 31759 , coordY : 0, taille : 2828 , nbHab : 41887
# La ville a pour coord X : 34921 , coordY : 0, taille : 3162 , nbHab : 29169
# La ville a pour coord X : 38662 , coordY : 0, taille : 3741 , nbHab : 30525
# La ville a pour coord X : 42267 , coordY : 0, taille : 3605 , nbHab : 27364
# La ville a pour coord X : 47834 , coordY : 0, taille : 5567 , nbHab : 21998
# La ville a pour coord X : 52933 , coordY : 0, taille : 5099 , nbHab : 19982
# La ville a pour coord X : 59177 , coordY : 0, taille : 6244 , nbHab : 18940
# La ville a pour coord X : 63649 , coordY : 0, taille : 4472 , nbHab : 16285
# La ville a pour coord X : 65381 , coordY : 0, taille : 1732 , nbHab : 13358
# La ville a pour coord X : 0 , coordY : 8485, taille : 4358 , nbHab : 13486
# Le pourcentage de carte recouverte par des lieu est de : -nan %
# log file name : log-configDpt06-MT-0006configVaccinNumRepli1.txt
# La ville a pour coord X : 8485 , coordY : 0, taille : 8485 , nbHab : 342669
# La ville a pour coord X : 13584 , coordY : 0, taille : 5099 , nbHab : 73438
# La ville a pour coord X : 18056 , coordY : 0, taille : 4472 , nbHab : 74545
# La ville a pour coord X : 24689 , coordY : 0, taille : 6633 , nbHab : 48870
# La ville a pour coord X : 28931 , coordY : 0, taille : 4242 , nbHab : 52178
# La ville a pour coord X : 31759 , coordY : 0, taille : 2828 , nbHab : 41887
# La ville a pour coord X : 34921 , coordY : 0, taille : 3162 , nbHab : 29169
# La ville a pour coord X : 38662 , coordY : 0, taille : 3741 , nbHab : 30525
# La ville a pour coord X : 42267 , coordY : 0, taille : 3605 , nbHab : 27364
# La ville a pour coord X : 47834 , coordY : 0, taille : 5567 , nbHab : 21998
# La ville a pour coord X : 52933 , coordY : 0, taille : 5099 , nbHab : 19982
# La ville a pour coord X : 59177 , coordY : 0, taille : 6244 , nbHab : 18940
# La ville a pour coord X : 63649 , coordY : 0, taille : 4472 , nbHab : 16285
# La ville a pour coord X : 65381 , coordY : 0, taille : 1732 , nbHab : 13358
# La ville a pour coord X : 0 , coordY : 8485, taille : 4358 , nbHab : 13486
# Le pourcentage de carte recouverte par des lieu est de : -nan %
# ***************STATISTICS******************
# Safe : 139170
# Contamined : 0
# Recovered : 1047
# Dead : 13
# log file name : log-configDpt06-MT-0291configVaccinNumRepli4.txt
# La ville a pour coord X : 8485 , coordY : 0, taille : 8485 , nbHab : 342669
# La ville a pour coord X : 13584 , coordY : 0, taille : 5099 , nbHab : 73438
# La ville a pour coord X : 18056 , coordY : 0, taille : 4472 , nbHab : 74545
# La ville a pour coord X : 24689 , coordY : 0, taille : 6633 , nbHab : 48870
# La ville a pour coord X : 28931 , coordY : 0, taille : 4242 , nbHab : 52178
# La ville a pour coord X : 31759 , coordY : 0, taille : 2828 , nbHab : 41887
# La ville a pour coord X : 34921 , coordY : 0, taille : 3162 , nbHab : 29169
# La ville a pour coord X : 38662 , coordY : 0, taille : 3741 , nbHab : 30525
# La ville a pour coord X : 42267 , coordY : 0, taille : 3605 , nbHab : 27364
# La ville a pour coord X : 47834 , coordY : 0, taille : 5567 , nbHab : 21998
# La ville a pour coord X : 52933 , coordY : 0, taille : 5099 , nbHab : 19982
# La ville a pour coord X : 59177 , coordY : 0, taille : 6244 , nbHab : 18940
# La ville a pour coord X : 63649 , coordY : 0, taille : 4472 , nbHab : 16285
# La ville a pour coord X : 65381 , coordY : 0, taille : 1732 , nbHab : 13358
# La ville a pour coord X : 0 , coordY : 8485, taille : 4358 , nbHab : 13486
# Le pourcentage de carte recouverte par des lieu est de : -nan %
# ***************STATISTICS******************
# Safe : 630475
# Contamined : 0
# Recovered : 454778
# Dead : 8040
# log file name : log-configDpt07-MT-0197configVaccinNumRepli3.txt
# La ville a pour coord X : 4582 , coordY : 0, taille : 4582 , nbHab : 16297
# La ville a pour coord X : 8323 , coordY : 0, taille : 3741 , nbHab : 12479
# La ville a pour coord X : 10968 , coordY : 0, taille : 2645 , nbHab : 10756
# La ville a pour coord X : 15550 , coordY : 0, taille : 4582 , nbHab : 10622
# La ville a pour coord X : 20746 , coordY : 0, taille : 5196 , nbHab : 8832
# La ville a pour coord X : 24210 , coordY : 0, taille : 3464 , nbHab : 8465
# La ville a pour coord X : 29108 , coordY : 0, taille : 4898 , nbHab : 7580
# La ville a pour coord X : 35741 , coordY : 0, taille : 6633 , nbHab : 7187
# La ville a pour coord X : 38903 , coordY : 0, taille : 3162 , nbHab : 4848
# La ville a pour coord X : 44733 , coordY : 0, taille : 5830 , nbHab : 3689
# La ville a pour coord X : 49091 , coordY : 0, taille : 4358 , nbHab : 3530
# La ville a pour coord X : 51540 , coordY : 0, taille : 2449 , nbHab : 3168
# La ville a pour coord X : 55898 , coordY : 0, taille : 4358 , nbHab : 3015
# La ville a pour coord X : 59503 , coordY : 0, taille : 3605 , nbHab : 2877
# La ville a pour coord X : 63375 , coordY : 0, taille : 3872 , nbHab : 3063
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 627834
# Contamined : 0
# Recovered : 457267
# Dead : 8192
# log file name : log-configDpt07-MT-0102configVaccinNumRepli2.txt
# ***************STATISTICS******************
# Safe : 630612
# Contamined : 0
# Recovered : 454529
# Dead : 8152
# La ville a pour coord X : 4582 , coordY : 0, taille : 4582 , nbHab : 16297
# La ville a pour coord X : 8323 , coordY : 0, taille : 3741 , nbHab : 12479
# La ville a pour coord X : 10968 , coordY : 0, taille : 2645 , nbHab : 10756
# La ville a pour coord X : 15550 , coordY : 0, taille : 4582 , nbHab : 10622
# La ville a pour coord X : 20746 , coordY : 0, taille : 5196 , nbHab : 8832
# La ville a pour coord X : 24210 , coordY : 0, taille : 3464 , nbHab : 8465
# La ville a pour coord X : 29108 , coordY : 0, taille : 4898 , nbHab : 7580
# La ville a pour coord X : 35741 , coordY : 0, taille : 6633 , nbHab : 7187
# La ville a pour coord X : 38903 , coordY : 0, taille : 3162 , nbHab : 4848
# La ville a pour coord X : 44733 , coordY : 0, taille : 5830 , nbHab : 3689
# La ville a pour coord X : 49091 , coordY : 0, taille : 4358 , nbHab : 3530
# La ville a pour coord X : 51540 , coordY : 0, taille : 2449 , nbHab : 3168
# La ville a pour coord X : 55898 , coordY : 0, taille : 4358 , nbHab : 3015
# La ville a pour coord X : 59503 , coordY : 0, taille : 3605 , nbHab : 2877
# La ville a pour coord X : 63375 , coordY : 0, taille : 3872 , nbHab : 3063
# log file name : log-configDpt07-MT-0007configVaccinNumRepli1.txt
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# La ville a pour coord X : 4582 , coordY : 0, taille : 4582 , nbHab : 16297
# La ville a pour coord X : 8323 , coordY : 0, taille : 3741 , nbHab : 12479
# La ville a pour coord X : 10968 , coordY : 0, taille : 2645 , nbHab : 10756
# La ville a pour coord X : 15550 , coordY : 0, taille : 4582 , nbHab : 10622
# La ville a pour coord X : 20746 , coordY : 0, taille : 5196 , nbHab : 8832
# La ville a pour coord X : 24210 , coordY : 0, taille : 3464 , nbHab : 8465
# La ville a pour coord X : 29108 , coordY : 0, taille : 4898 , nbHab : 7580
# La ville a pour coord X : 35741 , coordY : 0, taille : 6633 , nbHab : 7187
# La ville a pour coord X : 38903 , coordY : 0, taille : 3162 , nbHab : 4848
# La ville a pour coord X : 44733 , coordY : 0, taille : 5830 , nbHab : 3689
# La ville a pour coord X : 49091 , coordY : 0, taille : 4358 , nbHab : 3530
# La ville a pour coord X : 51540 , coordY : 0, taille : 2449 , nbHab : 3168
# La ville a pour coord X : 55898 , coordY : 0, taille : 4358 , nbHab : 3015
# La ville a pour coord X : 59503 , coordY : 0, taille : 3605 , nbHab : 2877
# La ville a pour coord X : 63375 , coordY : 0, taille : 3872 , nbHab : 3063
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 628743
# Contamined : 0
# Recovered : 456568
# Dead : 7982
# log file name : log-configDpt07-MT-0292configVaccinNumRepli4.txt
# La ville a pour coord X : 4582 , coordY : 0, taille : 4582 , nbHab : 16297
# La ville a pour coord X : 8323 , coordY : 0, taille : 3741 , nbHab : 12479
# La ville a pour coord X : 10968 , coordY : 0, taille : 2645 , nbHab : 10756
# La ville a pour coord X : 15550 , coordY : 0, taille : 4582 , nbHab : 10622
# La ville a pour coord X : 20746 , coordY : 0, taille : 5196 , nbHab : 8832
# La ville a pour coord X : 24210 , coordY : 0, taille : 3464 , nbHab : 8465
# La ville a pour coord X : 29108 , coordY : 0, taille : 4898 , nbHab : 7580
# La ville a pour coord X : 35741 , coordY : 0, taille : 6633 , nbHab : 7187
# La ville a pour coord X : 38903 , coordY : 0, taille : 3162 , nbHab : 4848
# La ville a pour coord X : 44733 , coordY : 0, taille : 5830 , nbHab : 3689
# La ville a pour coord X : 49091 , coordY : 0, taille : 4358 , nbHab : 3530
# La ville a pour coord X : 51540 , coordY : 0, taille : 2449 , nbHab : 3168
# La ville a pour coord X : 55898 , coordY : 0, taille : 4358 , nbHab : 3015
# La ville a pour coord X : 59503 , coordY : 0, taille : 3605 , nbHab : 2877
# La ville a pour coord X : 63375 , coordY : 0, taille : 3872 , nbHab : 3063
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 326046
# Contamined : 0
# Recovered : 1229
# Dead : 13
# log file name : log-configDpt08-MT-0198configVaccinNumRepli3.txt
# La ville a pour coord X : 5567 , coordY : 0, taille : 5567 , nbHab : 46436
# La ville a pour coord X : 9567 , coordY : 0, taille : 4000 , nbHab : 16092
# La ville a pour coord X : 13925 , coordY : 0, taille : 4358 , nbHab : 7467
# La ville a pour coord X : 18167 , coordY : 0, taille : 4242 , nbHab : 6476
# La ville a pour coord X : 24331 , coordY : 0, taille : 6164 , nbHab : 5836
# La ville a pour coord X : 27647 , coordY : 0, taille : 3316 , nbHab : 5689
# La ville a pour coord X : 32442 , coordY : 0, taille : 4795 , nbHab : 5018
# La ville a pour coord X : 38922 , coordY : 0, taille : 6480 , nbHab : 4320
# La ville a pour coord X : 43717 , coordY : 0, taille : 4795 , nbHab : 3572
# La ville a pour coord X : 46362 , coordY : 0, taille : 2645 , nbHab : 3568
# La ville a pour coord X : 52526 , coordY : 0, taille : 6164 , nbHab : 3280
# La ville a pour coord X : 55526 , coordY : 0, taille : 3000 , nbHab : 2918
# La ville a pour coord X : 59267 , coordY : 0, taille : 3741 , nbHab : 2879
# La ville a pour coord X : 65267 , coordY : 0, taille : 6000 , nbHab : 2423
# La ville a pour coord X : 67912 , coordY : 0, taille : 2645 , nbHab : 2313
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 326001
# Contamined : 0
# Recovered : 1265
# Dead : 22
# log file name : log-configDpt08-MT-0103configVaccinNumRepli2.txt
# ***************STATISTICS******************
# Safe : 325962
# Contamined : 0
# Recovered : 1305
# Dead : 21
# La ville a pour coord X : 5567 , coordY : 0, taille : 5567 , nbHab : 46436
# La ville a pour coord X : 9567 , coordY : 0, taille : 4000 , nbHab : 16092
# La ville a pour coord X : 13925 , coordY : 0, taille : 4358 , nbHab : 7467
# La ville a pour coord X : 18167 , coordY : 0, taille : 4242 , nbHab : 6476
# La ville a pour coord X : 24331 , coordY : 0, taille : 6164 , nbHab : 5836
# La ville a pour coord X : 27647 , coordY : 0, taille : 3316 , nbHab : 5689
# La ville a pour coord X : 32442 , coordY : 0, taille : 4795 , nbHab : 5018
# La ville a pour coord X : 38922 , coordY : 0, taille : 6480 , nbHab : 4320
# La ville a pour coord X : 43717 , coordY : 0, taille : 4795 , nbHab : 3572
# La ville a pour coord X : 46362 , coordY : 0, taille : 2645 , nbHab : 3568
# La ville a pour coord X : 52526 , coordY : 0, taille : 6164 , nbHab : 3280
# La ville a pour coord X : 55526 , coordY : 0, taille : 3000 , nbHab : 2918
# La ville a pour coord X : 59267 , coordY : 0, taille : 3741 , nbHab : 2879
# La ville a pour coord X : 65267 , coordY : 0, taille : 6000 , nbHab : 2423
# La ville a pour coord X : 67912 , coordY : 0, taille : 2645 , nbHab : 2313
# log file name : log-configDpt08-MT-0008configVaccinNumRepli1.txt
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# La ville a pour coord X : 5567 , coordY : 0, taille : 5567 , nbHab : 46436
# La ville a pour coord X : 9567 , coordY : 0, taille : 4000 , nbHab : 16092
# La ville a pour coord X : 13925 , coordY : 0, taille : 4358 , nbHab : 7467
# La ville a pour coord X : 18167 , coordY : 0, taille : 4242 , nbHab : 6476
# La ville a pour coord X : 24331 , coordY : 0, taille : 6164 , nbHab : 5836
# La ville a pour coord X : 27647 , coordY : 0, taille : 3316 , nbHab : 5689
# La ville a pour coord X : 32442 , coordY : 0, taille : 4795 , nbHab : 5018
# La ville a pour coord X : 38922 , coordY : 0, taille : 6480 , nbHab : 4320
# La ville a pour coord X : 43717 , coordY : 0, taille : 4795 , nbHab : 3572
# La ville a pour coord X : 46362 , coordY : 0, taille : 2645 , nbHab : 3568
# La ville a pour coord X : 52526 , coordY : 0, taille : 6164 , nbHab : 3280
# La ville a pour coord X : 55526 , coordY : 0, taille : 3000 , nbHab : 2918
# La ville a pour coord X : 59267 , coordY : 0, taille : 3741 , nbHab : 2879
# La ville a pour coord X : 65267 , coordY : 0, taille : 6000 , nbHab : 2423
# La ville a pour coord X : 67912 , coordY : 0, taille : 2645 , nbHab : 2313
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 326006
# Contamined : 0
# Recovered : 1266
# Dead : 16
# log file name : log-configDpt08-MT-0293configVaccinNumRepli4.txt
# La ville a pour coord X : 5567 , coordY : 0, taille : 5567 , nbHab : 46436
# La ville a pour coord X : 9567 , coordY : 0, taille : 4000 , nbHab : 16092
# La ville a pour coord X : 13925 , coordY : 0, taille : 4358 , nbHab : 7467
# La ville a pour coord X : 18167 , coordY : 0, taille : 4242 , nbHab : 6476
# La ville a pour coord X : 24331 , coordY : 0, taille : 6164 , nbHab : 5836
# La ville a pour coord X : 27647 , coordY : 0, taille : 3316 , nbHab : 5689
# La ville a pour coord X : 32442 , coordY : 0, taille : 4795 , nbHab : 5018
# La ville a pour coord X : 38922 , coordY : 0, taille : 6480 , nbHab : 4320
# La ville a pour coord X : 43717 , coordY : 0, taille : 4795 , nbHab : 3572
# La ville a pour coord X : 46362 , coordY : 0, taille : 2645 , nbHab : 3568
# La ville a pour coord X : 52526 , coordY : 0, taille : 6164 , nbHab : 3280
# La ville a pour coord X : 55526 , coordY : 0, taille : 3000 , nbHab : 2918
# La ville a pour coord X : 59267 , coordY : 0, taille : 3741 , nbHab : 2879
# La ville a pour coord X : 65267 , coordY : 0, taille : 6000 , nbHab : 2423
# La ville a pour coord X : 67912 , coordY : 0, taille : 2645 , nbHab : 2313
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 268316
# Contamined : 0
# Recovered : 1261
# Dead : 15
# log file name : log-configDpt09-MT-0199configVaccinNumRepli3.txt
# La ville a pour coord X : 6782 , coordY : 0, taille : 6782 , nbHab : 15659
# La ville a pour coord X : 11140 , coordY : 0, taille : 4358 , nbHab : 9493
# La ville a pour coord X : 15498 , coordY : 0, taille : 4358 , nbHab : 6418
# La ville a pour coord X : 19103 , coordY : 0, taille : 3605 , nbHab : 6031
# La ville a pour coord X : 26913 , coordY : 0, taille : 7810 , nbHab : 4828
# La ville a pour coord X : 33546 , coordY : 0, taille : 6633 , nbHab : 3873
# La ville a pour coord X : 37010 , coordY : 0, taille : 3464 , nbHab : 3495
# La ville a pour coord X : 40010 , coordY : 0, taille : 3000 , nbHab : 3024
# La ville a pour coord X : 46865 , coordY : 0, taille : 6855 , nbHab : 3102
# La ville a pour coord X : 50027 , coordY : 0, taille : 3162 , nbHab : 3218
# La ville a pour coord X : 52027 , coordY : 0, taille : 2000 , nbHab : 2859
# La ville a pour coord X : 55768 , coordY : 0, taille : 3741 , nbHab : 2405
# La ville a pour coord X : 59084 , coordY : 0, taille : 3316 , nbHab : 2252
# La ville a pour coord X : 65408 , coordY : 0, taille : 6324 , nbHab : 2348
# La ville a pour coord X : 68236 , coordY : 0, taille : 2828 , nbHab : 1484
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 268287
# Contamined : 0
# Recovered : 1283
# Dead : 22
# log file name : log-configDpt09-MT-0104configVaccinNumRepli2.txt
# ***************STATISTICS******************
# Safe : 268199
# Contamined : 0
# Recovered : 1380
# Dead : 13
# La ville a pour coord X : 6782 , coordY : 0, taille : 6782 , nbHab : 15659
# La ville a pour coord X : 11140 , coordY : 0, taille : 4358 , nbHab : 9493
# La ville a pour coord X : 15498 , coordY : 0, taille : 4358 , nbHab : 6418
# La ville a pour coord X : 19103 , coordY : 0, taille : 3605 , nbHab : 6031
# La ville a pour coord X : 26913 , coordY : 0, taille : 7810 , nbHab : 4828
# La ville a pour coord X : 33546 , coordY : 0, taille : 6633 , nbHab : 3873
# La ville a pour coord X : 37010 , coordY : 0, taille : 3464 , nbHab : 3495
# La ville a pour coord X : 40010 , coordY : 0, taille : 3000 , nbHab : 3024
# La ville a pour coord X : 46865 , coordY : 0, taille : 6855 , nbHab : 3102
# La ville a pour coord X : 50027 , coordY : 0, taille : 3162 , nbHab : 3218
# La ville a pour coord X : 52027 , coordY : 0, taille : 2000 , nbHab : 2859
# La ville a pour coord X : 55768 , coordY : 0, taille : 3741 , nbHab : 2405
# La ville a pour coord X : 59084 , coordY : 0, taille : 3316 , nbHab : 2252
# La ville a pour coord X : 65408 , coordY : 0, taille : 6324 , nbHab : 2348
# La ville a pour coord X : 68236 , coordY : 0, taille : 2828 , nbHab : 1484
# log file name : log-configDpt09-MT-0009configVaccinNumRepli1.txt
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# La ville a pour coord X : 6782 , coordY : 0, taille : 6782 , nbHab : 15659
# La ville a pour coord X : 11140 , coordY : 0, taille : 4358 , nbHab : 9493
# La ville a pour coord X : 15498 , coordY : 0, taille : 4358 , nbHab : 6418
# La ville a pour coord X : 19103 , coordY : 0, taille : 3605 , nbHab : 6031
# La ville a pour coord X : 26913 , coordY : 0, taille : 7810 , nbHab : 4828
# La ville a pour coord X : 33546 , coordY : 0, taille : 6633 , nbHab : 3873
# La ville a pour coord X : 37010 , coordY : 0, taille : 3464 , nbHab : 3495
# La ville a pour coord X : 40010 , coordY : 0, taille : 3000 , nbHab : 3024
# La ville a pour coord X : 46865 , coordY : 0, taille : 6855 , nbHab : 3102
# La ville a pour coord X : 50027 , coordY : 0, taille : 3162 , nbHab : 3218
# La ville a pour coord X : 52027 , coordY : 0, taille : 2000 , nbHab : 2859
# La ville a pour coord X : 55768 , coordY : 0, taille : 3741 , nbHab : 2405
# La ville a pour coord X : 59084 , coordY : 0, taille : 3316 , nbHab : 2252
# La ville a pour coord X : 65408 , coordY : 0, taille : 6324 , nbHab : 2348
# La ville a pour coord X : 68236 , coordY : 0, taille : 2828 , nbHab : 1484
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 268300
# Contamined : 0
# Recovered : 1274
# Dead : 18
# ...
# La ville a pour coord X : 15882 , coordY : 0, taille : 8602 , nbHab : 14858
# La ville a pour coord X : 21964 , coordY : 0, taille : 6082 , nbHab : 12125
# La ville a pour coord X : 26206 , coordY : 0, taille : 4242 , nbHab : 11167
# La ville a pour coord X : 30078 , coordY : 0, taille : 3872 , nbHab : 8862
# La ville a pour coord X : 32078 , coordY : 0, taille : 2000 , nbHab : 7779
# La ville a pour coord X : 37994 , coordY : 0, taille : 5916 , nbHab : 6552
# La ville a pour coord X : 43190 , coordY : 0, taille : 5196 , nbHab : 6038
# La ville a pour coord X : 45426 , coordY : 0, taille : 2236 , nbHab : 5157
# La ville a pour coord X : 48742 , coordY : 0, taille : 3316 , nbHab : 5503
# La ville a pour coord X : 52614 , coordY : 0, taille : 3872 , nbHab : 5225
# La ville a pour coord X : 60551 , coordY : 0, taille : 7937 , nbHab : 5286
# La ville a pour coord X : 65936 , coordY : 0, taille : 5385 , nbHab : 4744
# La ville a pour coord X : 70518 , coordY : 0, taille : 4582 , nbHab : 4473
# La ville a pour coord X : 75809 , coordY : 0, taille : 5291 , nbHab : 4261
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 686366
# Contamined : 0
# Recovered : 78306
# Dead : 1424
# log file name : log-configDpt69-MT-0354configVaccinNumRepli4.txt
# La ville a pour coord X : 6928 , coordY : 0, taille : 6928 , nbHab : 522969
# La ville a pour coord X : 10800 , coordY : 0, taille : 3872 , nbHab : 152212
# La ville a pour coord X : 14672 , coordY : 0, taille : 3872 , nbHab : 67285
# La ville a pour coord X : 19254 , coordY : 0, taille : 4582 , nbHab : 52795
# La ville a pour coord X : 24731 , coordY : 0, taille : 5477 , nbHab : 46927
# La ville a pour coord X : 27893 , coordY : 0, taille : 3162 , nbHab : 43294
# La ville a pour coord X : 31055 , coordY : 0, taille : 3162 , nbHab : 42244
# La ville a pour coord X : 34055 , coordY : 0, taille : 3000 , nbHab : 36291
# La ville a pour coord X : 38850 , coordY : 0, taille : 4795 , nbHab : 34640
# La ville a pour coord X : 42591 , coordY : 0, taille : 3741 , nbHab : 30697
# La ville a pour coord X : 46714 , coordY : 0, taille : 4123 , nbHab : 28930
# La ville a pour coord X : 48714 , coordY : 0, taille : 2000 , nbHab : 26553
# La ville a pour coord X : 51359 , coordY : 0, taille : 2645 , nbHab : 22175
# La ville a pour coord X : 54187 , coordY : 0, taille : 2828 , nbHab : 22286
# La ville a pour coord X : 0 , coordY : 6928, taille : 3605 , nbHab : 20914
# Le pourcentage de carte recouverte par des lieu est de : -0.000000 %
# ***************STATISTICS******************
# Safe : 562948
# Contamined : 0
# Recovered : 2444
# Dead : 30
# log file name : log-configDpt73-MT-0168configVaccinNumRepli2.txt
# ***************STATISTICS******************
# Safe : 563029
# Contamined : 0
# Recovered : 2366
# Dead : 27
# log file name : log-configDpt73-MT-0263configVaccinNumRepli3.txt
# La ville a pour coord X : 4582 , coordY : 0, taille : 4582 , nbHab : 58917
# La ville a pour coord X : 8187 , coordY : 0, taille : 3605 , nbHab : 30463
# La ville a pour coord X : 12429 , coordY : 0, taille : 4242 , nbHab : 19502
# La ville a pour coord X : 17906 , coordY : 0, taille : 5477 , nbHab : 12120
# La ville a pour coord X : 20551 , coordY : 0, taille : 2645 , nbHab : 8530
# La ville a pour coord X : 24015 , coordY : 0, taille : 3464 , nbHab : 7621
# La ville a pour coord X : 37394 , coordY : 0, taille : 13379 , nbHab : 7195
# La ville a pour coord X : 44943 , coordY : 0, taille : 7549 , nbHab : 7096
# La ville a pour coord X : 46943 , coordY : 0, taille : 2000 , nbHab : 6359
# La ville a pour coord X : 54154 , coordY : 0, taille : 7211 , nbHab : 6315
# La ville a pour coord X : 56982 , coordY : 0, taille : 2828 , nbHab : 6285
# La ville a pour coord X : 59431 , coordY : 0, taille : 2449 , nbHab : 5609
# La ville a pour coord X : 61431 , coordY : 0, taille : 2000 , nbHab : 5022
# La ville a pour coord X : 65903 , coordY : 0, taille : 4472 , nbHab : 4966
# La ville a pour coord X : 69508 , coordY : 0, taille : 3605 , nbHab : 4595
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# La ville a pour coord X : 4582 , coordY : 0, taille : 4582 , nbHab : 58917
# La ville a pour coord X : 8187 , coordY : 0, taille : 3605 , nbHab : 30463
# La ville a pour coord X : 12429 , coordY : 0, taille : 4242 , nbHab : 19502
# La ville a pour coord X : 17906 , coordY : 0, taille : 5477 , nbHab : 12120
# La ville a pour coord X : 20551 , coordY : 0, taille : 2645 , nbHab : 8530
# La ville a pour coord X : 24015 , coordY : 0, taille : 3464 , nbHab : 7621
# La ville a pour coord X : 37394 , coordY : 0, taille : 13379 , nbHab : 7195
# La ville a pour coord X : 44943 , coordY : 0, taille : 7549 , nbHab : 7096
# La ville a pour coord X : 46943 , coordY : 0, taille : 2000 , nbHab : 6359
# La ville a pour coord X : 54154 , coordY : 0, taille : 7211 , nbHab : 6315
# La ville a pour coord X : 56982 , coordY : 0, taille : 2828 , nbHab : 6285
# La ville a pour coord X : 59431 , coordY : 0, taille : 2449 , nbHab : 5609
# La ville a pour coord X : 61431 , coordY : 0, taille : 2000 , nbHab : 5022
# La ville a pour coord X : 65903 , coordY : 0, taille : 4472 , nbHab : 4966
# La ville a pour coord X : 69508 , coordY : 0, taille : 3605 , nbHab : 4595
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 562963
# Contamined : 0
# Recovered : 2418
# Dead : 41
# log file name : log-configDpt73-MT-0073configVaccinNumRepli1.txt
# La ville a pour coord X : 4582 , coordY : 0, taille : 4582 , nbHab : 58917
# La ville a pour coord X : 8187 , coordY : 0, taille : 3605 , nbHab : 30463
# La ville a pour coord X : 12429 , coordY : 0, taille : 4242 , nbHab : 19502
# La ville a pour coord X : 17906 , coordY : 0, taille : 5477 , nbHab : 12120
# La ville a pour coord X : 20551 , coordY : 0, taille : 2645 , nbHab : 8530
# La ville a pour coord X : 24015 , coordY : 0, taille : 3464 , nbHab : 7621
# La ville a pour coord X : 37394 , coordY : 0, taille : 13379 , nbHab : 7195
# La ville a pour coord X : 44943 , coordY : 0, taille : 7549 , nbHab : 7096
# La ville a pour coord X : 46943 , coordY : 0, taille : 2000 , nbHab : 6359
# La ville a pour coord X : 54154 , coordY : 0, taille : 7211 , nbHab : 6315
# La ville a pour coord X : 56982 , coordY : 0, taille : 2828 , nbHab : 6285
# La ville a pour coord X : 59431 , coordY : 0, taille : 2449 , nbHab : 5609
# La ville a pour coord X : 61431 , coordY : 0, taille : 2000 , nbHab : 5022
# La ville a pour coord X : 65903 , coordY : 0, taille : 4472 , nbHab : 4966
# La ville a pour coord X : 69508 , coordY : 0, taille : 3605 , nbHab : 4595
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 421879
# Contamined : 0
# Recovered : 13364
# Dead : 201
# log file name : log-configDpt74-MT-0169configVaccinNumRepli2.txt
# ***************STATISTICS******************
# Safe : 424834
# Contamined : 0
# Recovered : 10455
# Dead : 155
# La ville a pour coord X : 8185 , coordY : 0, taille : 8185 , nbHab : 130721
# La ville a pour coord X : 10421 , coordY : 0, taille : 2236 , nbHab : 36582
# La ville a pour coord X : 14421 , coordY : 0, taille : 4000 , nbHab : 35826
# La ville a pour coord X : 17583 , coordY : 0, taille : 3162 , nbHab : 16918
# La ville a pour coord X : 25707 , coordY : 0, taille : 8124 , nbHab : 16831
# La ville a pour coord X : 29830 , coordY : 0, taille : 4123 , nbHab : 15768
# La ville a pour coord X : 33146 , coordY : 0, taille : 3316 , nbHab : 15873
# La ville a pour coord X : 38342 , coordY : 0, taille : 5196 , nbHab : 12509
# La ville a pour coord X : 42584 , coordY : 0, taille : 4242 , nbHab : 11149
# La ville a pour coord X : 44584 , coordY : 0, taille : 2000 , nbHab : 10071
# La ville a pour coord X : 53528 , coordY : 0, taille : 8944 , nbHab : 11233
# La ville a pour coord X : 64436 , coordY : 0, taille : 10908 , nbHab : 9449
# La ville a pour coord X : 0 , coordY : 10908, taille : 2000 , nbHab : 9108
# La ville a pour coord X : 10816 , coordY : 10908, taille : 10816 , nbHab : 8640
# La ville a pour coord X : 12816 , coordY : 10908, taille : 2000 , nbHab : 9050
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# log file name : log-configDpt74-MT-0264configVaccinNumRepli3.txt
# La ville a pour coord X : 8185 , coordY : 0, taille : 8185 , nbHab : 130721
# La ville a pour coord X : 10421 , coordY : 0, taille : 2236 , nbHab : 36582
# La ville a pour coord X : 14421 , coordY : 0, taille : 4000 , nbHab : 35826
# La ville a pour coord X : 17583 , coordY : 0, taille : 3162 , nbHab : 16918
# La ville a pour coord X : 25707 , coordY : 0, taille : 8124 , nbHab : 16831
# La ville a pour coord X : 29830 , coordY : 0, taille : 4123 , nbHab : 15768
# La ville a pour coord X : 33146 , coordY : 0, taille : 3316 , nbHab : 15873
# La ville a pour coord X : 38342 , coordY : 0, taille : 5196 , nbHab : 12509
# La ville a pour coord X : 42584 , coordY : 0, taille : 4242 , nbHab : 11149
# La ville a pour coord X : 44584 , coordY : 0, taille : 2000 , nbHab : 10071
# La ville a pour coord X : 53528 , coordY : 0, taille : 8944 , nbHab : 11233
# La ville a pour coord X : 64436 , coordY : 0, taille : 10908 , nbHab : 9449
# La ville a pour coord X : 0 , coordY : 10908, taille : 2000 , nbHab : 9108
# La ville a pour coord X : 10816 , coordY : 10908, taille : 10816 , nbHab : 8640
# La ville a pour coord X : 12816 , coordY : 10908, taille : 2000 , nbHab : 9050
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 423634
# Contamined : 0
# Recovered : 11637
# Dead : 173
# log file name : log-configDpt74-MT-0074configVaccinNumRepli1.txt
# La ville a pour coord X : 8185 , coordY : 0, taille : 8185 , nbHab : 130721
# La ville a pour coord X : 10421 , coordY : 0, taille : 2236 , nbHab : 36582
# La ville a pour coord X : 14421 , coordY : 0, taille : 4000 , nbHab : 35826
# La ville a pour coord X : 17583 , coordY : 0, taille : 3162 , nbHab : 16918
# La ville a pour coord X : 25707 , coordY : 0, taille : 8124 , nbHab : 16831
# La ville a pour coord X : 29830 , coordY : 0, taille : 4123 , nbHab : 15768
# La ville a pour coord X : 33146 , coordY : 0, taille : 3316 , nbHab : 15873
# La ville a pour coord X : 38342 , coordY : 0, taille : 5196 , nbHab : 12509
# La ville a pour coord X : 42584 , coordY : 0, taille : 4242 , nbHab : 11149
# La ville a pour coord X : 44584 , coordY : 0, taille : 2000 , nbHab : 10071
# La ville a pour coord X : 53528 , coordY : 0, taille : 8944 , nbHab : 11233
# La ville a pour coord X : 64436 , coordY : 0, taille : 10908 , nbHab : 9449
# La ville a pour coord X : 0 , coordY : 10908, taille : 2000 , nbHab : 9108
# La ville a pour coord X : 10816 , coordY : 10908, taille : 10816 , nbHab : 8640
# La ville a pour coord X : 12816 , coordY : 10908, taille : 2000 , nbHab : 9050
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 732363
# Contamined : 0
# Recovered : 91528
# Dead : 1213
# log file name : log-configDpt75-MT-0170configVaccinNumRepli2.txt
# La ville a pour coord X : 0 , coordY : 0, taille : 10246 , nbHab : 2165423
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 731901
# Contamined : 0
# Recovered : 92001
# Dead : 1202
# log file name : log-configDpt75-MT-0265configVaccinNumRepli3.txt
# La ville a pour coord X : 0 , coordY : 0, taille : 10246 , nbHab : 2165423
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 730492
# Contamined : 0
# Recovered : 93442
# Dead : 1170
# log file name : log-configDpt75-MT-0075configVaccinNumRepli1.txt
# La ville a pour coord X : 0 , coordY : 0, taille : 10246 , nbHab : 2165423
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 975430
# Contamined : 0
# Recovered : 890383
# Dead : 8944
# log file name : log-configDpt70-MT-0355configVaccinNumRepli4.txt
# La ville a pour coord X : 3000 , coordY : 0, taille : 3000 , nbHab : 14914
# La ville a pour coord X : 7582 , coordY : 0, taille : 4582 , nbHab : 10646
# La ville a pour coord X : 12480 , coordY : 0, taille : 4898 , nbHab : 8046
# La ville a pour coord X : 17170 , coordY : 0, taille : 4690 , nbHab : 6623
# La ville a pour coord X : 21642 , coordY : 0, taille : 4472 , nbHab : 5553
# La ville a pour coord X : 29058 , coordY : 0, taille : 7416 , nbHab : 3797
# La ville a pour coord X : 35140 , coordY : 0, taille : 6082 , nbHab : 3745
# La ville a pour coord X : 39263 , coordY : 0, taille : 4123 , nbHab : 3150
# La ville a pour coord X : 42091 , coordY : 0, taille : 2828 , nbHab : 3249
# La ville a pour coord X : 47091 , coordY : 0, taille : 5000 , nbHab : 2954
# La ville a pour coord X : 51989 , coordY : 0, taille : 4898 , nbHab : 2735
# La ville a pour coord X : 55453 , coordY : 0, taille : 3464 , nbHab : 2533
# La ville a pour coord X : 58281 , coordY : 0, taille : 2828 , nbHab : 2418
# La ville a pour coord X : 62404 , coordY : 0, taille : 4123 , nbHab : 2297
# La ville a pour coord X : 65404 , coordY : 0, taille : 3000 , nbHab : 1978
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 233183
# Contamined : 0
# Recovered : 1122
# Dead : 18
# log file name : log-configDpt71-MT-0356configVaccinNumRepli4.txt
# La ville a pour coord X : 3872 , coordY : 0, taille : 3872 , nbHab : 45056
# La ville a pour coord X : 9068 , coordY : 0, taille : 5196 , nbHab : 33908
# La ville a pour coord X : 13310 , coordY : 0, taille : 4242 , nbHab : 21269
# La ville a pour coord X : 17433 , coordY : 0, taille : 4123 , nbHab : 17678
# La ville a pour coord X : 25307 , coordY : 0, taille : 7874 , nbHab : 12987
# La ville a pour coord X : 30307 , coordY : 0, taille : 5000 , nbHab : 9214
# La ville a pour coord X : 35205 , coordY : 0, taille : 4898 , nbHab : 8576
# La ville a pour coord X : 41121 , coordY : 0, taille : 5916 , nbHab : 7741
# La ville a pour coord X : 46506 , coordY : 0, taille : 5385 , nbHab : 6760
# La ville a pour coord X : 50111 , coordY : 0, taille : 3605 , nbHab : 7742
# La ville a pour coord X : 53273 , coordY : 0, taille : 3162 , nbHab : 6615
# La ville a pour coord X : 58068 , coordY : 0, taille : 4795 , nbHab : 6433
# La ville a pour coord X : 64392 , coordY : 0, taille : 6324 , nbHab : 6060
# La ville a pour coord X : 67997 , coordY : 0, taille : 3605 , nbHab : 6148
# La ville a pour coord X : 71159 , coordY : 0, taille : 3162 , nbHab : 6190
# Le pourcentage de carte recouverte par des lieu est de : -0.000000 %
# ***************STATISTICS******************
# Safe : 547354
# Contamined : 0
# Recovered : 3113
# Dead : 36
# ERREUR: Impossible d'ouvrir le fichier.
# log file name : log-configDpt72-MT-0357configVaccinNumRepli4.txt
# ./replicationSimulationFrance.sh : ligne 5 : 534529 Erreur de segmentation  (core dumped) ./exe $valeurStatut ${@: -1}
#
# real	604m22,496s
# user	587m43,355s
# sys	15m55,229s
# ***************STATISTICS******************
# Safe : 1025
# Contamined : 0
# Recovered : 2145911
# Dead : 17487
# ERREUR: Impossible d'ouvrir le fichier.
# log file name : log-configDpt76-MT-0171configVaccinNumRepli2.txt
# ./replicationSimulationFrance.sh : ligne 5 : 534525 Erreur de segmentation  (core dumped) ./exe $valeurStatut ${@: -1}
#
# real	620m16,871s
# user	603m47,636s
# sys	13m37,596s
# ***************STATISTICS******************
# Safe : 1028
# Contamined : 0
# Recovered : 2146020
# Dead : 17375
# ERREUR: Impossible d'ouvrir le fichier.
# log file name : log-configDpt76-MT-0266configVaccinNumRepli3.txt
# ./replicationSimulationFrance.sh : ligne 5 : 534528 Erreur de segmentation  (core dumped) ./exe $valeurStatut ${@: -1}
#
# real	620m44,635s
# user	609m2,583s
# sys	9m26,507s
# ***************STATISTICS******************
# Safe : 926
# Contamined : 0
# Recovered : 2146182
# Dead : 17315
# ERREUR: Impossible d'ouvrir le fichier.
# log file name : log-configDpt76-MT-0076configVaccinNumRepli1.txt
# ./replicationSimulationFrance.sh : ligne 5 : 534526 Erreur de segmentation  (core dumped) ./exe $valeurStatut ${@: -1}
#
# real	696m20,884s
# user	605m18,783s
# sys	11m54,435s
# ./replicationSimulationFrance.sh: error reading input file: Expiration de la clé

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
import pandas as pd
import csv
from statistics import mean,variance
'''
Qu'est ce qu'on a comme résultats pour le moment :
- Les listes
- Taux de mortalité des gens contaminé
- Taux de mortalité par tranche d'age des gens contaminé
- Reffectif
- Taux d'incidence

On peut donc envisager beaucoup d'autres résultats.


'''

NB_REPLICATION = 4
NOM_EXPERIENCE = "Vaccin"


#listVille = ["configLyon"]
figureNouvCas = plt.figure()
axes = figureNouvCas.add_subplot()

pasFigure = 6 * NB_REPLICATION
compteurFigure = 0
for nbDpt in range(0,95):
    ville = "configDpt" + f"{nbDpt+1:02}"
    print(ville)
    print("############################ Ville : " + ville + "#####################")
    compteurFigure = compteurFigure + pasFigure
    listResReplication = [[] for x in range(0,NB_REPLICATION)]


    for replication in listResReplication:

        listNumIteration = []
        listNbNouvCas = []
        listNbPersonneHosp = []
        listNbPersonneRea = []
        listNbNouvHosp = []
        listNbNouvRea = []
        listNbNouvMort = []
        nbCasCovidConnuTotal = 0
        listAgeMort = []
        listAgeNouvCasSymptomatique = []
        listReffectif = []
        listTauxIncidence = []
        
        temp = nbDpt + (95*(listResReplication.index(replication))) + 1
        stringFormat = f"{temp:04}"
        print(stringFormat)
        print("log-"+str(ville)+ "-MT-"+stringFormat+"config"+NOM_EXPERIENCE+"NumRepli"+str(listResReplication.index(replication)+1)+".txt")
        f = open("log-"+str(ville)+ "-MT-"+stringFormat+"config"+NOM_EXPERIENCE+"NumRepli"+str(listResReplication.index(replication)+1)+".txt", "r")
        fileLines = f.readlines()
        i = 0
        for line in fileLines:
            if("CompteurRand:" in line):
                listSplit = line.split(":")
                nbRandomGenere = (int(listSplit[1]))
            elif("NbHumainSimuDepart:" in line):
                listSplit = line.split(":")
                nbHumainSimuDepart = (int(listSplit[1]))
            elif("##" not in line):
                if(i == 0):
                    listNumIteration.append(int(line))
                    i = i + 1
                elif(i==1):
                    listNbNouvCas.append(int(line))
                    i = i + 1
                elif(i==2):
                    listNbPersonneHosp.append(int(line))
                    i = i + 1
                elif(i==3):
                    listNbPersonneRea.append(int(line))
                    i = i + 1
                elif(i==4):
                    listNbNouvHosp.append(int(line))
                    i = i + 1
                elif(i==5):
                    listNbNouvRea.append(int(line))
                    i = i + 1
                elif(i==6):
                    listNbNouvMort.append(int(line))
                    i = i + 1
                elif(i==7):
                    nbCasCovidConnuTotal = (int(line))
                    i = i + 1
                elif(i==8):
                    listReffectif.append(float(line))
                    i = i + 1
                elif(i==9):
                    listTauxIncidence.append(float(line))
                    i = i + 1
                elif("AgeC:" in line):
                    listSplit = line.split(":")
                    listAgeNouvCasSymptomatique.append(int(listSplit[1]))
                elif("AgeD:" in line):
                    listSplit = line.split(":")
                    listAgeMort.append(int(listSplit[1]))

            else:
                i = 0

        f.close()


        #label=str(ville)+ "-MT-"+stringFormat+"config"+NOM_EXPERIENCE+"NumRepli"+str(listResReplication.index(replication)+1) 
        axes.plot(listNumIteration, listNbNouvCas, label="test")
        """
        plt.figure((listResReplication.index(replication)*6)+compteurFigure)
        print("Courbe des nouveaux cas sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvCas)  # Matplotlib plot.
        plt.xlabel("Jour")
        plt.ylabel("Nouv Cas")
        plt.title(label="Courbe nouvCas"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvCas"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        string = "nouvCas"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv"
        with open(string, "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvCas)

        plt.figure((listResReplication.index(replication)*6+1)+compteurFigure)
        print("Courbe des nouvelles hospitalisation sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvHosp)
        plt.xlabel("Jour")
        plt.ylabel("Nouv Hosp")
        plt.title(label="Courbe nouvHosp"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvHosp"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("nouvHosp"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvHosp)

        plt.figure((listResReplication.index(replication)*6+2)+compteurFigure)
        print("Courbe des nouvelles réanimation sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvRea)
        plt.xlabel("Jour")
        plt.ylabel("Nouv Rea")
        plt.title(label="Courbe nouvRea"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvRea"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("nouvRea"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvRea)

        plt.figure((listResReplication.index(replication)*6+3)+compteurFigure)
        print("Courbe des nouveaux morts sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvMort)
        plt.xlabel("Jour")
        plt.ylabel("Nouv Mort")
        plt.title(label="Courbe nouvMort"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvMort"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("nouvMort"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvMort)

        print("Courbe de Reffectif sur la réplication num : " +str(listResReplication.index(replication)))
        plt.figure((listResReplication.index(replication)*6+4)+compteurFigure)
        plt.plot(listNumIteration, listReffectif)
        plt.xlabel("Jour")
        plt.ylabel("Reffectif")
        plt.title(label="Courbe Reffectif"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("Reffectif"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("Reffectif"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listReffectif)
            
        print("Courbe du taux d'incidence sur la réplication num : " +str(listResReplication.index(replication)))
        plt.figure((listResReplication.index(replication)*6+5)+compteurFigure)
        plt.plot(listNumIteration, listTauxIncidence)
        plt.xlabel("Jour")
        plt.ylabel("Taux Incidence")
        plt.title(label="Courbe Taux incidence"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("TauxIncidence"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("TauxIncidence"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listTauxIncidence)
        """
        nbMortTotal = sum(listNbNouvMort)
        try:
            tauxDeMortCasConnu = (nbMortTotal / nbCasCovidConnuTotal) * 100
        except:
            tauxDeMortCasConnu = 0
        tauxMortalitePopulationGobale = (nbMortTotal / nbHumainSimuDepart) * 100

        print("Le taux de mort de cas connu est de : " + str(tauxDeMortCasConnu) + "%")
        print("Le taux de mortalité du département sur l'ensemble de la population est de : " + str(tauxMortalitePopulationGobale) + "%")

        ## IL ME FAUT L'AGE DES GENS CONTAMINE AUSSI ... 


        nbAge0 = 0
        nbAge1 = 0
        nbAge2 = 0
        nbAge3 = 0
        nbAge4 = 0
        nbAge5 = 0
        nbAge6 = 0
        nbAge7 = 0

        for i in listAgeNouvCasSymptomatique:
            if i == 0:
                nbAge0 = nbAge0 + 1
            elif i == 1:
                nbAge1 = nbAge1 + 1
            elif i == 2:
                nbAge2 = nbAge2 + 1
            elif i == 3:
                nbAge3 = nbAge3 + 1
            elif i == 4:
                nbAge4 = nbAge4 + 1
            elif i == 5:
                nbAge5 = nbAge5 + 1
            elif i == 6:
                nbAge6 = nbAge6 + 1
            elif i == 7:
                nbAge7 = nbAge7 + 1


        nbAgeMort0 = 0
        nbAgeMort1 = 0
        nbAgeMort2 = 0
        nbAgeMort3 = 0
        nbAgeMort4 = 0
        nbAgeMort5 = 0
        nbAgeMort6 = 0
        nbAgeMort7 = 0

        for i in listAgeMort:
            if i == 0:
                nbAgeMort0 = nbAgeMort0 + 1
            elif i == 1:
                nbAgeMort1 = nbAgeMort1 + 1
            elif i == 2:
                nbAgeMort2 = nbAgeMort2 + 1
            elif i == 3:
                nbAgeMort3 = nbAgeMort3 + 1
            elif i == 4:
                nbAgeMort4 = nbAgeMort4 + 1
            elif i == 5:
                nbAgeMort5 = nbAgeMort5 + 1
            elif i == 6:
                nbAgeMort6 = nbAgeMort6 + 1
            elif i == 7:
                nbAgeMort7 = nbAgeMort7 + 1

        try :
            print("Le taux de mortalité pour les 0 - 15 ans est de : " + str( (nbAgeMort0/nbAge0) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 0 n'a été malade")
        try :
            print("Le taux de mortalité pour les 15 - 25 ans est de : " + str( (nbAgeMort1/nbAge1) * 100) + "%") 
        except ZeroDivisionError:
            print ("Aucun age 1 n'a été malade")
        try :
            print("Le taux de mortalité pour les 25 - 35 ans est de : " + str( (nbAgeMort2/nbAge2) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 2 n'a été malade")
        try:
            print("Le taux de mortalité pour les 35 - 45 ans est de : " + str( (nbAgeMort3/nbAge3) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 3 n'a été malade")
        try :
            print("Le taux de mortalité pour les 45 - 55 ans est de : " + str( (nbAgeMort4/nbAge4) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 4 n'a été malade")
        try:
            print("Le taux de mortalité pour les 55 - 65 ans est de : " + str( (nbAgeMort5/nbAge5) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 5 n'a été malade")
        try:
            print("Le taux de mortalité pour les 65 - 75 ans est de : " + str( (nbAgeMort6/nbAge6) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 6 n'a été malade")
        try:
            print("Le taux de mortalité pour les 75 + ans est de : " + str( (nbAgeMort7/nbAge7) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucune age 7 n'a été malade")

        print("############\n################")
        print(" replication = " + str(listResReplication.index(replication)))
        replication.append(listNumIteration)
        replication.append(listNbNouvCas)
        replication.append(listNbPersonneHosp)
        replication.append(listNbPersonneRea)
        replication.append(listNbNouvHosp)
        replication.append(listNbNouvMort)
        replication.append(listReffectif)
        replication.append(nbCasCovidConnuTotal)
        replication.append(tauxDeMortCasConnu)
        replication.append(tauxMortalitePopulationGobale)
        try :
            replication.append((nbAgeMort0/nbAge0) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort1/nbAge1) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort2/nbAge2) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort3/nbAge3) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort4/nbAge4) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort5/nbAge5) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort6/nbAge6) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort7/nbAge7) * 100)
        except ZeroDivisionError:
            replication.append(0)
            
        replication.append(int(nbRandomGenere))



    dataframeResultats = pd.DataFrame({"Champs":["nbCasCovidConnuTotal","tauxDeMortCasConnu","tauxMortalitePopulationGobale", "tauxDeMort0-15ans", "tauxDeMort15-25ans","tauxDeMort25-35ans","tauxDeMort35-45ans","tauxDeMort45-55ans","tauxDeMort55-65ans","tauxDeMort65-75ans","tauxDeMort75+ans","nbRandomGenere"]})
    numRepli = 1
    listResReplicationTruncated = []
    for replication in listResReplication:
        nomRepli = "R"+str(numRepli)
        dataframeResultats[nomRepli] = replication[-12:]
        listResReplicationTruncated.append(replication[-12:])
        numRepli = numRepli + 1

    
    if(NB_REPLICATION > 1):
        listMoyenne = [mean(list(map(float,list(r)))) for r in zip(*listResReplicationTruncated)]

        listVariance = [variance(list(map(float,list(r)))) for r in zip(*listResReplicationTruncated)]

        '''
        Confidence Intervals Using the t Distribution
        If we’re working with a small sample (n <30), we can use the t.interval() function from the scipy.stats library to calculate a confidence interval for a population mean.

        The following example shows how to calculate a confidence interval for the true population mean height (in inches) of a certain species of plant, using a sample of 15 plants:



        ###########
        Confidence Intervals Using the Normal Distribution
        If we’re working with larger samples (n≥30), we can assume that the sampling distribution of the sample mean is normally distributed (thanks to the Central Limit Theorem) and can instead use the norm.interval() function from the scipy.stats library.




        '''

        listIntervalle95 = [st.t.interval(alpha=0.95, df=len(r)-1, loc=np.mean(r), scale=st.sem(r)) for r in zip(*listResReplicationTruncated)]

        dataframeResultats["Moyenne"] = listMoyenne
        dataframeResultats["Variance"] = listVariance
        dataframeResultats["Intervalle95%"] = listIntervalle95

    print(dataframeResultats)

    dataframeResultats.to_csv("stats"+str(ville) + str(NOM_EXPERIENCE)+".csv", sep="|")
    dataframeResultats.to_html("stats"+str(ville) + str(NOM_EXPERIENCE)+".html",float_format='%.3f')
# Out:
# configDpt01
# ############################ Ville : configDpt01#####################
# 0001
# log-configDpt01-MT-0001configVaccinNumRepli1.txt
# Le taux de mort de cas connu est de : 1.2254901960784315%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.003065453564509405%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.49504950495049505%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.0%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.45871559633027525%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.4018691588785046%
# Le taux de mortalité pour les 65 - 75 ans est de : 2.6881720430107525%
# Le taux de mortalité pour les 75 + ans est de : 6.369426751592357%
# ############
# ################
#  replication = 0
# 0096
# log-configDpt01-MT-0096configVaccinNumRepli2.txt
# Le taux de mort de cas connu est de : 1.0863661053775122%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.003065453564509405%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.42016806722689076%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.43478260869565216%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.0746887966804977%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.4492753623188406%
# Le taux de mortalité pour les 75 + ans est de : 5.319148936170213%
# ############
# ################
#  replication = 1
# 0191
# log-configDpt01-MT-0191configVaccinNumRepli3.txt
# Le taux de mort de cas connu est de : 1.1397720455908817%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.0029121808862839346%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.0%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.46511627906976744%
# Le taux de mortalité pour les 55 - 65 ans est de : 0.9803921568627451%
# Le taux de mortalité pour les 65 - 75 ans est de : 2.3391812865497075%
# Le taux de mortalité pour les 75 + ans est de : 7.100591715976331%
# ############
# ################
#  replication = 2
# 0286
# log-configDpt01-MT-0286configVaccinNumRepli4.txt
# Le taux de mort de cas connu est de : 1.8094089264173705%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.004598180346764107%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 1.530612244897959%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.9302325581395349%
# Le taux de mortalité pour les 55 - 65 ans est de : 6.806282722513089%
# Le taux de mortalité pour les 65 - 75 ans est de : 2.127659574468085%
# Le taux de mortalité pour les 75 + ans est de : 4.9079754601226995%
# ############
# ################
#  replication = 3
#                            Champs            R1            R2            R3  \
# 0            nbCasCovidConnuTotal  1.632000e+03  1.841000e+03  1.667000e+03
# 1              tauxDeMortCasConnu  1.225490e+00  1.086366e+00  1.139772e+00
# 2   tauxMortalitePopulationGobale  3.065454e-03  3.065454e-03  2.912181e-03
# 3               tauxDeMort0-15ans  0.000000e+00  0.000000e+00  0.000000e+00
# 4              tauxDeMort15-25ans  0.000000e+00  0.000000e+00  0.000000e+00
# 5              tauxDeMort25-35ans  4.950495e-01  0.000000e+00  0.000000e+00
# 6              tauxDeMort35-45ans  0.000000e+00  4.201681e-01  0.000000e+00
# 7              tauxDeMort45-55ans  4.587156e-01  4.347826e-01  4.651163e-01
# 8              tauxDeMort55-65ans  1.401869e+00  2.074689e+00  9.803922e-01
# 9              tauxDeMort65-75ans  2.688172e+00  1.449275e+00  2.339181e+00
# 10               tauxDeMort75+ans  6.369427e+00  5.319149e+00  7.100592e+00
# 11                 nbRandomGenere  7.193317e+08  7.193627e+08  7.193364e+08
#
#               R4       Moyenne      Variance  \
# 0   1.658000e+03  1.699500e+03  9.119000e+03
# 1   1.809409e+00  1.315259e+00  1.118101e-01
# 2   4.598180e-03  3.410317e-03  6.323402e-07
# 3   0.000000e+00  0.000000e+00  0.000000e+00
# 4   0.000000e+00  0.000000e+00  0.000000e+00
# 5   0.000000e+00  1.237624e-01  6.126850e-02
# 6   1.530612e+00  4.876951e-01  5.226430e-01
# 7   9.302326e-01  5.722118e-01  5.713883e-02
# 8   6.806283e+00  2.815808e+00  7.280374e+00
# 9   2.127660e+00  2.151072e+00  2.723094e-01
# 10  4.907975e+00  5.924286e+00  9.936411e-01
# 11  7.193242e+08  7.193388e+08  2.789625e+08
#
#                                    Intervalle95%
# 0       (1547.5486030436105, 1851.4513969563895)
# 1       (0.7831859119060377, 1.8473327248260603)
# 2   (0.002144979315476541, 0.004675654865556884)
# 3                                     (nan, nan)
# 4                                     (nan, nan)
# 5      (-0.2701047407530028, 0.5176294932282504)
# 6       (-0.662664654272635, 1.6380548103350598)
# 7      (0.19185008293200329, 0.9525734381856115)
# 8         (-1.47765672112536, 7.109273138592778)
# 9        (1.3207197306147536, 2.981424402558939)
# 10        (4.338129818100251, 7.510441613830549)
# 11        (719312178.8674016, 719365332.6325984)
# configDpt02
# ############################ Ville : configDpt02#####################
# 0002
# log-configDpt02-MT-0002configVaccinNumRepli1.txt
# Le taux de mort de cas connu est de : 1.4748809340912583%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.018065113443267077%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.12674271229404308%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.26455026455026454%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.3875968992248062%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.8206330597889802%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.5625%
# Le taux de mortalité pour les 65 - 75 ans est de : 3.943661971830986%
# Le taux de mortalité pour les 75 + ans est de : 6.645569620253164%
# ############
# ################
#  replication = 0
# 0097
# log-configDpt02-MT-0097configVaccinNumRepli2.txt
# Le taux de mort de cas connu est de : 1.405152224824356%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.016936043853062886%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.12970168612191957%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.14104372355430184%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.7453416149068323%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.9280742459396751%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.7434620174346203%
# Le taux de mortalité pour les 65 - 75 ans est de : 2.303523035230352%
# Le taux de mortalité pour les 75 + ans est de : 7.363013698630137%
# ############
# ################
#  replication = 1
# 0192
# log-configDpt02-MT-0192configVaccinNumRepli3.txt
# Le taux de mort de cas connu est de : 1.4526710402999063%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.01750057864816498%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.13003901170351106%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.2890173410404624%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.36363636363636365%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.9615384615384616%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.3349514563106795%
# Le taux de mortalité pour les 65 - 75 ans est de : 2.3088023088023086%
# Le taux de mortalité pour les 75 + ans est de : 8.59504132231405%
# ############
# ################
#  replication = 2
# 0287
# log-configDpt02-MT-0287configVaccinNumRepli4.txt
# Le taux de mort de cas connu est de : 1.5628591128476212%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.012796122022314178%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.3976143141153081%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.8992805755395683%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.9823182711198428%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.9434628975265018%
# Le taux de mortalité pour les 65 - 75 ans est de : 3.024193548387097%
# Le taux de mortalité pour les 75 + ans est de : 7.6923076923076925%
# ############
# ################
#  replication = 3
#                            Champs            R1            R2            R3  \
# 0            nbCasCovidConnuTotal  6.509000e+03  6.405000e+03  6.402000e+03
# 1              tauxDeMortCasConnu  1.474881e+00  1.405152e+00  1.452671e+00
# 2   tauxMortalitePopulationGobale  1.806511e-02  1.693604e-02  1.750058e-02
# 3               tauxDeMort0-15ans  0.000000e+00  0.000000e+00  0.000000e+00
# 4              tauxDeMort15-25ans  1.267427e-01  1.297017e-01  1.300390e-01
# 5              tauxDeMort25-35ans  2.645503e-01  1.410437e-01  2.890173e-01
# 6              tauxDeMort35-45ans  3.875969e-01  7.453416e-01  3.636364e-01
# 7              tauxDeMort45-55ans  8.206331e-01  9.280742e-01  9.615385e-01
# 8              tauxDeMort55-65ans  1.562500e+00  1.743462e+00  1.334951e+00
# 9              tauxDeMort65-75ans  3.943662e+00  2.303523e+00  2.308802e+00
# 10               tauxDeMort75+ans  6.645570e+00  7.363014e+00  8.595041e+00
# 11                 nbRandomGenere  1.305919e+09  1.305943e+09  1.305907e+09
#
#               R4       Moyenne      Variance  \
# 0   4.351000e+03  5.916750e+03  1.092063e+06
# 1   1.562859e+00  1.473891e+00  4.363870e-03
# 2   1.279612e-02  1.632446e-02  5.745444e-06
# 3   0.000000e+00  0.000000e+00  0.000000e+00
# 4   3.976143e-01  1.960244e-01  1.806374e-02
# 5   0.000000e+00  1.736528e-01  1.759666e-02
# 6   8.992806e-01  5.989639e-01  7.055720e-02
# 7   9.823183e-01  9.231410e-01  5.169510e-03
# 8   1.943463e+00  1.646094e+00  6.723548e-02
# 9   3.024194e+00  2.895045e+00  6.032852e-01
# 10  7.692308e+00  7.573983e+00  6.543401e-01
# 11  1.305619e+09  1.305847e+09  2.323157e+10
#
#                                    Intervalle95%
# 0         (4253.892937855403, 7579.607062144597)
# 1       (1.3687752681846501, 1.5790063878469207)
# 2   (0.012510357231614817, 0.020138571751789743)
# 3                                     (nan, nan)
# 4    (-0.017838209291511586, 0.4098870714089025)
# 5     (-0.03742672890737106, 0.3847323934798854)
# 6      (0.17629353852818258, 1.0216341881256026)
# 7       (0.8087331744619144, 1.0375488447315655)
# 8       (1.2334930371698605, 2.0586951484660405)
# 9          (1.659119330514261, 4.13097110161111)
# 10        (6.286822135038949, 8.861144031713572)
# 11      (1305604436.7364721, 1306089502.2635279)
# configDpt03
# ############################ Ville : configDpt03#####################
# 0003
# log-configDpt03-MT-0003configVaccinNumRepli1.txt
# Le taux de mort de cas connu est de : 1.6967616280989009%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.15298757348016964%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.055772448410485224%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.23101357204735778%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.371451313345715%
# Le taux de mortalité pour les 45 - 55 ans est de : 1.111385527290689%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.567604479650369%
# Le taux de mortalité pour les 65 - 75 ans est de : 3.5818287711124053%
# Le taux de mortalité pour les 75 + ans est de : 7.645875251509055%
# ############
# ################
#  replication = 0
# 0098
# log-configDpt03-MT-0098configVaccinNumRepli2.txt
# /tmp/ipykernel_1522559/3049923515.py:360: DeprecationWarning: Use of keyword argument `alpha` for method `interval` is deprecated. Use first positional argument or keyword argument `confidence` instead.
#   listIntervalle95 = [st.t.interval(alpha=0.95, df=len(r)-1, loc=np.mean(r), scale=st.sem(r)) for r in zip(*listResReplicationTruncated)]
# /home/local.isima.fr/beantunes/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2343: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/local.isima.fr/beantunes/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2344: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# /tmp/ipykernel_1522559/3049923515.py:360: DeprecationWarning: Use of keyword argument `alpha` for method `interval` is deprecated. Use first positional argument or keyword argument `confidence` instead.
#   listIntervalle95 = [st.t.interval(alpha=0.95, df=len(r)-1, loc=np.mean(r), scale=st.sem(r)) for r in zip(*listResReplicationTruncated)]
# /home/local.isima.fr/beantunes/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2343: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/local.isima.fr/beantunes/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2344: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# Le taux de mort de cas connu est de : 1.76175852594149%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.16221445047994643%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.08062348830959419%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.30916245081506466%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.6704486848891181%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.9061964241978937%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.6713709677419355%
# Le taux de mortalité pour les 65 - 75 ans est de : 4.023668639053255%
# Le taux de mortalité pour les 75 + ans est de : 7.550952221850986%
# ############
# ################
#  replication = 1
# 0193
# log-configDpt03-MT-0193configVaccinNumRepli3.txt
# Le taux de mort de cas connu est de : 1.663153734685812%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.150308802738299%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.11120378092855157%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.20771513353115725%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.5709624796084829%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.9542451676045999%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.4740622505985637%
# Le taux de mortalité pour les 65 - 75 ans est de : 3.5249927766541465%
# Le taux de mortalité pour les 75 + ans est de : 7.3244147157190636%
# ############
# ################
#  replication = 2
# 0288
# log-configDpt03-MT-0288configVaccinNumRepli4.txt
# Le taux de mort de cas connu est de : 1.7613429827170284%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.15864275615745219%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.05730659025787965%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.2530933633295838%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.51034112275047%
# Le taux de mortalité pour les 45 - 55 ans est de : 1.101052116466846%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.2538234504963777%
# Le taux de mortalité pour les 65 - 75 ans est de : 4.525799942346498%
# Le taux de mortalité pour les 75 + ans est de : 7.563611014290695%
# ############
# ################
#  replication = 3
#                            Champs            R1            R2            R3  \
# 0            nbCasCovidConnuTotal  3.029300e+04  3.093500e+04  3.036400e+04
# 1              tauxDeMortCasConnu  1.696762e+00  1.761759e+00  1.663154e+00
# 2   tauxMortalitePopulationGobale  1.529876e-01  1.622145e-01  1.503088e-01
# 3               tauxDeMort0-15ans  0.000000e+00  0.000000e+00  0.000000e+00
# 4              tauxDeMort15-25ans  5.577245e-02  8.062349e-02  1.112038e-01
# 5              tauxDeMort25-35ans  2.310136e-01  3.091625e-01  2.077151e-01
# 6              tauxDeMort35-45ans  3.714513e-01  6.704487e-01  5.709625e-01
# 7              tauxDeMort45-55ans  1.111386e+00  9.061964e-01  9.542452e-01
# 8              tauxDeMort55-65ans  2.567604e+00  2.671371e+00  2.474062e+00
# 9              tauxDeMort65-75ans  3.581829e+00  4.023669e+00  3.524993e+00
# 10               tauxDeMort75+ans  7.645875e+00  7.550952e+00  7.324415e+00
# 11                 nbRandomGenere  1.680266e+09  1.680352e+09  1.680271e+09
#
#               R4       Moyenne      Variance  \
# 0   3.026100e+04  3.046325e+04  1.007629e+05
# 1   1.761343e+00  1.720754e+00  2.407420e-03
# 2   1.586428e-01  1.560384e-01  2.902070e-05
# 3   0.000000e+00  0.000000e+00  0.000000e+00
# 4   5.730659e-02  7.622658e-02  6.730250e-04
# 5   2.530934e-01  2.502461e-01  1.886006e-03
# 6   5.103411e-01  5.308009e-01  1.564178e-02
# 7   1.101052e+00  1.018220e+00  1.072768e-02
# 8   2.253823e+00  2.491715e+00  3.164650e-02
# 9   4.525800e+00  3.914073e+00  2.159969e-01
# 10  7.563611e+00  7.521213e+00  1.898408e-02
# 11  1.679942e+09  1.680208e+09  3.288130e+10
#
#                                  Intervalle95%
# 0     (29958.145248114924, 30968.354751885076)
# 1      (1.642680105459719, 1.7988283302618968)
# 2   (0.14746633920166172, 0.16461045222627194)
# 3                                   (nan, nan)
# 4   (0.03494591275229199, 0.11750724120096333)
# 5    (0.1811422283289315, 0.31935003153265024)
# 6    (0.33179121157200075, 0.7298105887248922)
# 7     (0.8534096547949785, 1.1830299629850358)
# 8      (2.2086452471415146, 2.774785327102109)
# 9       (3.174544144479286, 4.653600920103866)
# 10      (7.301970206733356, 7.740456394951543)
# 11    (1679919265.0530717, 1680496344.4469283)
# configDpt04
# ############################ Ville : configDpt04#####################
# 0004
# log-configDpt04-MT-0004configVaccinNumRepli1.txt
# Le taux de mort de cas connu est de : 1.6853932584269662%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.01095503566472722%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.9174311926605505%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.8849557522123894%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.0%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.0%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.4492753623188406%
# Le taux de mortalité pour les 65 - 75 ans est de : 4.320987654320987%
# Le taux de mortalité pour les 75 + ans est de : 6.862745098039216%
# ############
# ################
#  replication = 0
# 0099
# log-configDpt04-MT-0099configVaccinNumRepli2.txt
# Le taux de mort de cas connu est de : 1.3232514177693762%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.008520583294787838%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.7518796992481203%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.0%
# Le taux de mortalité pour les 45 - 55 ans est de : 1.3986013986013985%
# Le taux de mortalité pour les 55 - 65 ans est de : 0.7874015748031495%
# Le taux de mortalité pour les 65 - 75 ans est de : 0.9900990099009901%
# Le taux de mortalité pour les 75 + ans est de : 8.653846153846153%
# ############
# ################
#  replication = 1
# 0194
# log-configDpt04-MT-0194configVaccinNumRepli3.txt
# Le taux de mort de cas connu est de : 1.3888888888888888%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.009129196387272684%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.0%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.7462686567164178%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.941176470588235%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.9801980198019802%
# Le taux de mortalité pour les 75 + ans est de : 8.080808080808081%
# ############
# ################
#  replication = 2
# 0289
# log-configDpt04-MT-0289configVaccinNumRepli4.txt
# Le taux de mort de cas connu est de : 1.899335232668566%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.01217226184969691%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.8%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.7936507936507936%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.0%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.5423728813559325%
# Le taux de mortalité pour les 65 - 75 ans est de : 6.25%
# Le taux de mortalité pour les 75 + ans est de : 7.547169811320755%
# ############
# ################
#  replication = 3
#                            Champs            R1            R2            R3  \
# 0            nbCasCovidConnuTotal  1.068000e+03  1.058000e+03  1.080000e+03
# 1              tauxDeMortCasConnu  1.685393e+00  1.323251e+00  1.388889e+00
# 2   tauxMortalitePopulationGobale  1.095504e-02  8.520583e-03  9.129196e-03
# 3               tauxDeMort0-15ans  0.000000e+00  0.000000e+00  0.000000e+00
# 4              tauxDeMort15-25ans  9.174312e-01  0.000000e+00  0.000000e+00
# 5              tauxDeMort25-35ans  8.849558e-01  7.518797e-01  0.000000e+00
# 6              tauxDeMort35-45ans  0.000000e+00  0.000000e+00  0.000000e+00
# 7              tauxDeMort45-55ans  0.000000e+00  1.398601e+00  7.462687e-01
# 8              tauxDeMort55-65ans  1.449275e+00  7.874016e-01  2.941176e+00
# 9              tauxDeMort65-75ans  4.320988e+00  9.900990e-01  1.980198e+00
# 10               tauxDeMort75+ans  6.862745e+00  8.653846e+00  8.080808e+00
# 11                 nbRandomGenere  1.860542e+09  1.860631e+09  1.860554e+09
#
#               R4       Moyenne      Variance  \
# 0   1.053000e+03  1.064750e+03  1.422500e+02
# 1   1.899335e+00  1.574217e+00  7.179742e-02
# 2   1.217226e-02  1.019427e-02  2.808942e-06
# 3   0.000000e+00  0.000000e+00  0.000000e+00
# 4   8.000000e-01  4.293578e-01  2.480958e-01
# 5   0.000000e+00  4.092089e-01  2.262207e-01
# 6   7.936508e-01  1.984127e-01  1.574704e-01
# 7   0.000000e+00  5.362175e-01  4.542953e-01
# 8   2.542373e+00  1.930057e+00  9.780352e-01
# 9   6.250000e+00  3.385321e+00  5.597772e+00
# 10  7.547170e+00  7.786142e+00  5.831694e-01
# 11  1.860215e+09  1.860486e+09  3.417667e+10
#
#                                    Intervalle95%
# 0       (1045.7717035265543, 1083.7282964734457)
# 1        (1.1478483119705065, 2.000586086906392)
# 2   (0.007527395571228567, 0.012861143027013761)
# 3                                     (nan, nan)
# 4        (-0.3632180419774347, 1.22193363830771)
# 5     (-0.34761930872785035, 1.1660370344581052)
# 6      (-0.4330250605722744, 0.8298504573976712)
# 7      (-0.5362896698603483, 1.6087246975192564)
# 8      (0.35640586469102464, 3.5037072798420543)
# 9       (-0.3794510275121321, 7.150093369524111)
# 10        (6.570996329637525, 9.001288242369577)
# 11      (1860191506.3983104, 1860779843.1016896)
# configDpt05
# ############################ Ville : configDpt05#####################
# 0005
# log-configDpt05-MT-0005configVaccinNumRepli1.txt
# Le taux de mort de cas connu est de : 1.1494252873563218%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.008497379974507861%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.0%
# Le taux de mortalité pour les 45 - 55 ans est de : 2.083333333333333%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.34375%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.680672268907563%
# Le taux de mortalité pour les 75 + ans est de : 3.7383177570093453%
# ############
# ################
#  replication = 0
# 0100
# log-configDpt05-MT-0100configVaccinNumRepli2.txt
# Le taux de mort de cas connu est de : 1.6822429906542056%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.01274606996176179%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 1.6%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.7142857142857143%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.127659574468085%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.5384615384615385%
# Le taux de mortalité pour les 75 + ans est de : 10.1010101010101%
# ############
# ################
#  replication = 1
# 0195
# log-configDpt05-MT-0195configVaccinNumRepli3.txt
# Le taux de mort de cas connu est de : 1.5223596574690772%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.01132983996601048%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.7407407407407408%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.7874015748031495%
# Le taux de mortalité pour les 55 - 65 ans est de : 0.0%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.8691588785046727%
# Le taux de mortalité pour les 75 + ans est de : 10.084033613445378%
# ############
# ################
#  replication = 2
# 0290
# log-configDpt05-MT-0290configVaccinNumRepli4.txt
# Le taux de mort de cas connu est de : 1.2264150943396228%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.009205494972383516%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 1.6%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.6802721088435374%
# Le taux de mortalité pour les 55 - 65 ans est de : 0.7352941176470588%
# Le taux de mortalité pour les 65 - 75 ans est de : 0.9259259259259258%
# Le taux de mortalité pour les 75 + ans est de : 8.080808080808081%
# ############
# ################
#  replication = 3
#                            Champs            R1            R2            R3  \
# 0            nbCasCovidConnuTotal  1.044000e+03  1.070000e+03  1.051000e+03
# 1              tauxDeMortCasConnu  1.149425e+00  1.682243e+00  1.522360e+00
# 2   tauxMortalitePopulationGobale  8.497380e-03  1.274607e-02  1.132984e-02
# 3               tauxDeMort0-15ans  0.000000e+00  0.000000e+00  0.000000e+00
# 4              tauxDeMort15-25ans  0.000000e+00  0.000000e+00  0.000000e+00
# 5              tauxDeMort25-35ans  0.000000e+00  0.000000e+00  0.000000e+00
# 6              tauxDeMort35-45ans  0.000000e+00  1.600000e+00  7.407407e-01
# 7              tauxDeMort45-55ans  2.083333e+00  7.142857e-01  7.874016e-01
# 8              tauxDeMort55-65ans  2.343750e+00  2.127660e+00  0.000000e+00
# 9              tauxDeMort65-75ans  1.680672e+00  1.538462e+00  1.869159e+00
# 10               tauxDeMort75+ans  3.738318e+00  1.010101e+01  1.008403e+01
# 11                 nbRandomGenere  2.016040e+09  2.016125e+09  2.016047e+09
#
#               R4       Moyenne      Variance  \
# 0   1.060000e+03  1.056250e+03  1.269167e+02
# 1   1.226415e+00  1.395111e+00  6.248559e-02
# 2   9.205495e-03  1.044470e-02  3.802487e-06
# 3   0.000000e+00  0.000000e+00  0.000000e+00
# 4   0.000000e+00  0.000000e+00  0.000000e+00
# 5   0.000000e+00  0.000000e+00  0.000000e+00
# 6   1.600000e+00  9.851852e-01  5.954458e-01
# 7   6.802721e-01  1.066323e+00  4.616909e-01
# 8   7.352941e-01  1.301676e+00  1.261105e+00
# 9   9.259259e-01  1.503555e+00  1.666368e-01
# 10  8.080808e+00  8.001042e+00  8.975300e+00
# 11  2.015712e+09  2.015981e+09  3.364687e+10
#
#                                     Intervalle95%
# 0        (1038.3237099998096, 1074.1762900001904)
# 1        (0.9973508215804384, 1.7928706933291751)
# 2   (0.0073418163965261515, 0.013547576040805672)
# 3                                      (nan, nan)
# 4                                      (nan, nan)
# 5                                      (nan, nan)
# 6       (-0.2426843192497451, 2.2130546896201158)
# 7     (-0.014878591643961325, 2.1475249572768287)
# 8      (-0.48525089422708656, 3.0886027402846583)
# 9          (0.853998640448487, 2.153110665451363)
# 10        (3.233927905267011, 12.768156870869442)
# 11       (2015689277.3546972, 2016273036.1453028)
# configDpt06
# ############################ Ville : configDpt06#####################
# 0006
# log-configDpt06-MT-0006configVaccinNumRepli1.txt
# /tmp/ipykernel_1522559/3049923515.py:360: DeprecationWarning: Use of keyword argument `alpha` for method `interval` is deprecated. Use first positional argument or keyword argument `confidence` instead.
#   listIntervalle95 = [st.t.interval(alpha=0.95, df=len(r)-1, loc=np.mean(r), scale=st.sem(r)) for r in zip(*listResReplicationTruncated)]
# /home/local.isima.fr/beantunes/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2343: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/local.isima.fr/beantunes/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2344: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# /tmp/ipykernel_1522559/3049923515.py:360: DeprecationWarning: Use of keyword argument `alpha` for method `interval` is deprecated. Use first positional argument or keyword argument `confidence` instead.
#   listIntervalle95 = [st.t.interval(alpha=0.95, df=len(r)-1, loc=np.mean(r), scale=st.sem(r)) for r in zip(*listResReplicationTruncated)]
# /home/local.isima.fr/beantunes/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2343: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/local.isima.fr/beantunes/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2344: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# /tmp/ipykernel_1522559/3049923515.py:360: DeprecationWarning: Use of keyword argument `alpha` for method `interval` is deprecated. Use first positional argument or keyword argument `confidence` instead.
#   listIntervalle95 = [st.t.interval(alpha=0.95, df=len(r)-1, loc=np.mean(r), scale=st.sem(r)) for r in zip(*listResReplicationTruncated)]
# /home/local.isima.fr/beantunes/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2343: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/local.isima.fr/beantunes/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2344: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# Le taux de mort de cas connu est de : 1.7619050706642374%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7449626833278047%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.10436884315377011%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.17770383953721383%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.6236933797909407%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.9138724523339908%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.777163277461074%
# Le taux de mortalité pour les 65 - 75 ans est de : 3.9733067423487%
# Le taux de mortalité pour les 75 + ans est de : 7.655231716147719%
# ############
# ################
#  replication = 0
# 0101
# log-configDpt06-MT-0101configVaccinNumRepli2.txt
# Le taux de mort de cas connu est de : 1.7599831564111983%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.748618044875046%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.09505191986943812%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.1421612297894118%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.6464695483378974%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.9932629428914989%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.6174815216654235%
# Le taux de mortalité pour les 65 - 75 ans est de : 3.9962246342614445%
# Le taux de mortalité pour les 75 + ans est de : 7.6731897362411%
# ############
# ################
#  replication = 1
# 0196
# log-configDpt06-MT-0196configVaccinNumRepli3.txt
# Le taux de mort de cas connu est de : 1.7371839470374966%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7347276709955286%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.08904234054152281%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.1830988546979803%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.5974112180550946%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.8824254375154056%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.7233562416658117%
# Le taux de mortalité pour les 65 - 75 ans est de : 3.8828049951969263%
# Le taux de mortalité pour les 75 + ans est de : 7.645088030940121%
# ############
# ################
#  replication = 2
# 0291
# log-configDpt06-MT-0291configVaccinNumRepli4.txt
# Le taux de mort de cas connu est de : 1.7182219352061137%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7294273967520285%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.12107850224085585%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.16721465476749647%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.5766591978878988%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.9777241840076915%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.6774584635349963%
# Le taux de mortalité pour les 65 - 75 ans est de : 3.8026662592154015%
# Le taux de mortalité pour les 75 + ans est de : 7.544224765868887%
# ############
# ################
#  replication = 3
#                            Champs            R1            R2            R3  \
# 0            nbCasCovidConnuTotal  4.626810e+05  4.654590e+05  4.628180e+05
# 1              tauxDeMortCasConnu  1.761905e+00  1.759983e+00  1.737184e+00
# 2   tauxMortalitePopulationGobale  7.449627e-01  7.486180e-01  7.347277e-01
# 3               tauxDeMort0-15ans  0.000000e+00  0.000000e+00  0.000000e+00
# 4              tauxDeMort15-25ans  1.043688e-01  9.505192e-02  8.904234e-02
# 5              tauxDeMort25-35ans  1.777038e-01  1.421612e-01  1.830989e-01
# 6              tauxDeMort35-45ans  6.236934e-01  6.464695e-01  5.974112e-01
# 7              tauxDeMort45-55ans  9.138725e-01  9.932629e-01  8.824254e-01
# 8              tauxDeMort55-65ans  2.777163e+00  2.617482e+00  2.723356e+00
# 9              tauxDeMort65-75ans  3.973307e+00  3.996225e+00  3.882805e+00
# 10               tauxDeMort75+ans  7.655232e+00  7.673190e+00  7.645088e+00
# 11                 nbRandomGenere  3.275356e+09  3.275814e+09  3.275493e+09
#
#               R4       Moyenne      Variance  \
# 0   4.645500e+05  4.638770e+05  1.835850e+06
# 1   1.718222e+00  1.744324e+00  4.288671e-04
# 2   7.294274e-01  7.394339e-01  7.906489e-05
# 3   0.000000e+00  0.000000e+00  0.000000e+00
# 4   1.210785e-01  1.023854e-01  1.950611e-04
# 5   1.672147e-01  1.675446e-01  3.298564e-04
# 6   5.766592e-01  6.110583e-01  9.277143e-04
# 7   9.777242e-01  9.418213e-01  2.748089e-03
# 8   2.677458e+00  2.698865e+00  4.603984e-03
# 9   3.802666e+00  3.913751e+00  7.882087e-03
# 10  7.544225e+00  7.629434e+00  3.361916e-03
# 11  3.275474e+09  3.275534e+09  3.834860e+10
#
#                                  Intervalle95%
# 0     (461720.99538488116, 466033.00461511884)
# 1      (1.7113707164305045, 1.777276338229018)
# 2      (0.725285041192814, 0.7535828567823899)
# 3                                   (nan, nan)
# 4    (0.08016169878033716, 0.1246091041224563)
# 5   (0.13864492861804267, 0.19644436077800853)
# 6     (0.5625922209995939, 0.6595244510363218)
# 7     (0.8584058099778441, 1.0252366983964492)
# 8      (2.590896148168632, 2.8068336039950212)
# 9       (3.772480084579184, 4.055021230932052)
# 10      (7.537171207008148, 7.721695917590765)
# 11      (3275222882.994972, 3275846095.005028)
# configDpt07
# ############################ Ville : configDpt07#####################
# 0007
# log-configDpt07-MT-0007configVaccinNumRepli1.txt
# Le taux de mort de cas connu est de : 1.583710407239819%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.006397017162283187%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.0%
# Le taux de mortalité pour les 45 - 55 ans est de : 1.1299435028248588%
# Le taux de mortalité pour les 55 - 65 ans est de : 5.291005291005291%
# Le taux de mortalité pour les 65 - 75 ans est de : 0.7936507936507936%
# Le taux de mortalité pour les 75 + ans est de : 5.797101449275362%
# ############
# ################
#  replication = 0
# 0102
# log-configDpt07-MT-0102configVaccinNumRepli2.txt
# Le taux de mort de cas connu est de : 1.7094017094017095%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.006701637027153815%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 1.3513513513513513%
# Le taux de mortalité pour les 35 - 45 ans est de : 1.1976047904191618%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.6024096385542169%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.3157894736842104%
# Le taux de mortalité pour les 65 - 75 ans est de : 4.195804195804196%
# Le taux de mortalité pour les 75 + ans est de : 7.627118644067797%
# ############
# ################
#  replication = 1
# 0197
# log-configDpt07-MT-0197configVaccinNumRepli3.txt
# Le taux de mort de cas connu est de : 1.0466988727858293%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.003960058243318163%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.0%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.0%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.0689655172413794%
# Le taux de mortalité pour les 65 - 75 ans est de : 2.158273381294964%
# Le taux de mortalité pour les 75 + ans est de : 6.363636363636363%
# ############
# ################
#  replication = 2
# 0292
# log-configDpt07-MT-0292configVaccinNumRepli4.txt
# Le taux de mort de cas connu est de : 1.24804992199688%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.004873917837930047%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.0%
# Le taux de mortalité pour les 45 - 55 ans est de : 1.0582010582010581%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.6490066225165565%
# Le taux de mortalité pour les 65 - 75 ans est de : 3.149606299212598%
# Le taux de mortalité pour les 75 + ans est de : 4.8%
# ############
# ################
#  replication = 3
#                            Champs            R1            R2            R3  \
# 0            nbCasCovidConnuTotal  1.326000e+03  1.287000e+03  1.242000e+03
# 1              tauxDeMortCasConnu  1.583710e+00  1.709402e+00  1.046699e+00
# 2   tauxMortalitePopulationGobale  6.397017e-03  6.701637e-03  3.960058e-03
# 3               tauxDeMort0-15ans  0.000000e+00  0.000000e+00  0.000000e+00
# 4              tauxDeMort15-25ans  0.000000e+00  0.000000e+00  0.000000e+00
# 5              tauxDeMort25-35ans  0.000000e+00  1.351351e+00  0.000000e+00
# 6              tauxDeMort35-45ans  0.000000e+00  1.197605e+00  0.000000e+00
# 7              tauxDeMort45-55ans  1.129944e+00  6.024096e-01  0.000000e+00
# 8              tauxDeMort55-65ans  5.291005e+00  1.315789e+00  2.068966e+00
# 9              tauxDeMort65-75ans  7.936508e-01  4.195804e+00  2.158273e+00
# 10               tauxDeMort75+ans  5.797101e+00  7.627119e+00  6.363636e+00
# 11                 nbRandomGenere  3.637358e+09  3.637808e+09  3.637490e+09
#
#               R4       Moyenne      Variance  \
# 0   1.282000e+03  1.284250e+03  1.180250e+03
# 1   1.248050e+00  1.396965e+00  9.245087e-02
# 2   4.873918e-03  5.483158e-03  1.670279e-06
# 3   0.000000e+00  0.000000e+00  0.000000e+00
# 4   0.000000e+00  0.000000e+00  0.000000e+00
# 5   0.000000e+00  3.378378e-01  4.565376e-01
# 6   0.000000e+00  2.994012e-01  3.585643e-01
# 7   1.058201e+00  6.976385e-01  2.708870e-01
# 8   2.649007e+00  2.831192e+00  2.987102e+00
# 9   3.149606e+00  2.574334e+00  2.101348e+00
# 10  4.800000e+00  6.146964e+00  1.391507e+00
# 11  3.637474e+09  3.637532e+09  3.722347e+10
#
#                                     Intervalle95%
# 0        (1229.5838997078122, 1338.9161002921878)
# 1        (0.9131421427745283, 1.8807883129375904)
# 2   (0.0034266724880480173, 0.007539642647294589)
# 3                                      (nan, nan)
# 4                                      (nan, nan)
# 5       (-0.7373129409744134, 1.4129886166500891)
# 6       (-0.6534270375102584, 1.2522294327198393)
# 7       (-0.1305422682860905, 1.5258193680761574)
# 8        (0.08104326494433467, 5.581340187279384)
# 9        (0.26769247748427105, 4.880974857497005)
# 10         (4.269923104593287, 8.024005123896474)
# 11       (3637225452.6846375, 3637839454.3153625)
# configDpt08
# ############################ Ville : configDpt08#####################
# 0008
# log-configDpt08-MT-0008configVaccinNumRepli1.txt
# Le taux de mort de cas connu est de : 0.9332376166547021%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.0048044585375228216%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.0%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.5%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1695906432748537%
# Le taux de mortalité pour les 65 - 75 ans est de : 2.941176470588235%
# Le taux de mortalité pour les 75 + ans est de : 4.545454545454546%
# ############
# ################
#  replication = 0
# 0103
# log-configDpt08-MT-0103configVaccinNumRepli2.txt
# Le taux de mort de cas connu est de : 1.6858237547892718%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.008130622140423236%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.6451612903225806%
# Le taux de mortalité pour les 45 - 55 ans est de : 1.4814814814814816%
# Le taux de mortalité pour les 55 - 65 ans est de : 4.0%
# Le taux de mortalité pour les 65 - 75 ans est de : 0.6622516556291391%
# Le taux de mortalité pour les 75 + ans est de : 7.18954248366013%
# ############
# ################
#  replication = 1
# 0198
# log-configDpt08-MT-0198configVaccinNumRepli3.txt
# Le taux de mort de cas connu est de : 1.1755485893416928%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.005543606004834024%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.0%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.6451612903225806%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.342281879194631%
# Le taux de mortalité pour les 65 - 75 ans est de : 2.797202797202797%
# Le taux de mortalité pour les 75 + ans est de : 6.557377049180328%
# ############
# ################
#  replication = 2
# 0293
# log-configDpt08-MT-0293configVaccinNumRepli4.txt
# Le taux de mort de cas connu est de : 1.393188854489164%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.00665232720580083%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.6329113924050633%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.6451612903225806%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.8518518518518516%
# Le taux de mortalité pour les 65 - 75 ans est de : 3.2679738562091507%
# Le taux de mortalité pour les 75 + ans est de : 6.299212598425196%
# ############
# ################
#  replication = 3
#                            Champs            R1            R2            R3  \
# 0            nbCasCovidConnuTotal  1.393000e+03  1.305000e+03  1.276000e+03
# 1              tauxDeMortCasConnu  9.332376e-01  1.685824e+00  1.175549e+00
# 2   tauxMortalitePopulationGobale  4.804459e-03  8.130622e-03  5.543606e-03
# 3               tauxDeMort0-15ans  0.000000e+00  0.000000e+00  0.000000e+00
# 4              tauxDeMort15-25ans  0.000000e+00  0.000000e+00  0.000000e+00
# 5              tauxDeMort25-35ans  0.000000e+00  0.000000e+00  0.000000e+00
# 6              tauxDeMort35-45ans  0.000000e+00  6.451613e-01  0.000000e+00
# 7              tauxDeMort45-55ans  5.000000e-01  1.481481e+00  6.451613e-01
# 8              tauxDeMort55-65ans  1.169591e+00  4.000000e+00  1.342282e+00
# 9              tauxDeMort65-75ans  2.941176e+00  6.622517e-01  2.797203e+00
# 10               tauxDeMort75+ans  4.545455e+00  7.189542e+00  6.557377e+00
# 11                 nbRandomGenere  3.935730e+09  3.936212e+09  3.935843e+09
#
#               R4       Moyenne      Variance  \
# 0   1.292000e+03  1.316500e+03  2.741667e+03
# 1   1.393189e+00  1.296950e+00  1.025032e-01
# 2   6.652327e-03  6.282753e-03  2.094299e-06
# 3   0.000000e+00  0.000000e+00  0.000000e+00
# 4   0.000000e+00  0.000000e+00  0.000000e+00
# 5   0.000000e+00  0.000000e+00  0.000000e+00
# 6   6.329114e-01  3.195182e-01  1.361475e-01
# 7   6.451613e-01  8.179510e-01  2.003594e-01
# 8   1.851852e+00  2.090931e+00  1.703682e+00
# 9   3.267974e+00  2.417151e+00  1.407538e+00
# 10  6.299213e+00  6.147897e+00  1.281139e+00
# 11  3.935881e+09  3.935917e+09  4.300343e+10
#
#                                   Intervalle95%
# 0      (1233.1820808101616, 1399.8179191898384)
# 1      (0.7875016799383541, 1.8063977276990613)
# 2   (0.003979983937337577, 0.00858552300695288)
# 3                                    (nan, nan)
# 4                                    (nan, nan)
# 5                                    (nan, nan)
# 6    (-0.26761404663142085, 0.9066503879952429)
# 7      (0.1056953434568293, 1.5302066876064921)
# 8       (0.01398419707082832, 4.16787799008984)
# 9       (0.5293288696668246, 4.304973520147837)
# 10      (4.3468322735431295, 7.948961064816971)
# 11     (3935586542.7809196, 3936246495.2190804)
# configDpt09
# ############################ Ville : configDpt09#####################
# 0009
# log-configDpt09-MT-0009configVaccinNumRepli1.txt
# Le taux de mort de cas connu est de : 1.1187607573149743%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.008480823553204122%
# ...
# /home/local.isima.fr/beantunes/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2343: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/local.isima.fr/beantunes/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2344: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# Le taux de mort de cas connu est de : 1.018898712296351%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.4880189066009435%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.044642857142857144%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.10106015994713775%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.3592031244401448%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.5365260151748146%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.4718706233649552%
# Le taux de mortalité pour les 65 - 75 ans est de : 2.2401193139448172%
# Le taux de mortalité pour les 75 + ans est de : 4.734074325669646%
# ############
# ################
#  replication = 0
# 0164
# log-configDpt69-MT-0164configVaccinNumRepli2.txt
# Le taux de mort de cas connu est de : 0.9909775673457769%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.4751173799025135%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.05425631431244153%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08149089533270598%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.34837574299208074%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.5330679239872131%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.4001850464819139%
# Le taux de mortalité pour les 65 - 75 ans est de : 2.176168875448427%
# Le taux de mortalité pour les 75 + ans est de : 4.639579988515311%
# ############
# ################
#  replication = 1
# 0259
# log-configDpt69-MT-0259configVaccinNumRepli3.txt
# Le taux de mort de cas connu est de : 1.0143170862286393%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.4858331107553417%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.053164698640102974%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08715947278203354%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.3566667867564939%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.5110891897407986%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.49891044473264%
# Le taux de mortalité pour les 65 - 75 ans est de : 2.221168755493664%
# Le taux de mortalité pour les 75 + ans est de : 4.685824826364611%
# ############
# ################
#  replication = 2
# 0354
# log-configDpt69-MT-0354configVaccinNumRepli4.txt
# Le taux de mort de cas connu est de : 0.9945214588242096%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.47682336690395877%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.043974962340590756%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.09279755633101662%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.34658932756283056%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.5305263157894736%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.4524585517925463%
# Le taux de mortalité pour les 65 - 75 ans est de : 2.147813090772322%
# Le taux de mortalité pour les 75 + ans est de : 4.606772825255546%
# ############
# ################
#  replication = 3
#                            Champs            R1            R2            R3  \
# 0            nbCasCovidConnuTotal  8.984210e+05  8.993140e+05  8.984370e+05
# 1              tauxDeMortCasConnu  1.018899e+00  9.909776e-01  1.014317e+00
# 2   tauxMortalitePopulationGobale  4.880189e-01  4.751174e-01  4.858331e-01
# 3               tauxDeMort0-15ans  0.000000e+00  0.000000e+00  0.000000e+00
# 4              tauxDeMort15-25ans  4.464286e-02  5.425631e-02  5.316470e-02
# 5              tauxDeMort25-35ans  1.010602e-01  8.149090e-02  8.715947e-02
# 6              tauxDeMort35-45ans  3.592031e-01  3.483757e-01  3.566668e-01
# 7              tauxDeMort45-55ans  5.365260e-01  5.330679e-01  5.110892e-01
# 8              tauxDeMort55-65ans  1.471871e+00  1.400185e+00  1.498910e+00
# 9              tauxDeMort65-75ans  2.240119e+00  2.176169e+00  2.221169e+00
# 10               tauxDeMort75+ans  4.734074e+00  4.639580e+00  4.685825e+00
# 11                 nbRandomGenere  4.892714e+10  4.893048e+10  4.893167e+10
#
#               R4       Moyenne      Variance  \
# 0   8.993270e+05  8.988748e+05  2.649949e+05
# 1   9.945215e-01  1.004679e+00  1.953326e-04
# 2   4.768234e-01  4.814482e-01  4.129000e-05
# 3   0.000000e+00  0.000000e+00  0.000000e+00
# 4   4.397496e-02  4.900971e-02  2.973629e-05
# 5   9.279756e-02  9.062702e-02  6.968476e-05
# 6   3.465893e-01  3.527087e-01  3.802175e-05
# 7   5.305263e-01  5.278024e-01  1.301928e-04
# 8   1.452459e+00  1.455856e+00  1.740317e-03
# 9   2.147813e+00  2.196318e+00  1.764943e-03
# 10  4.606773e+00  4.666563e+00  3.077248e-03
# 11  4.892535e+10  4.892866e+10  8.562360e+12
#
#                                  Intervalle95%
# 0       (898055.6256039259, 899693.8743960741)
# 1     (0.9824395418808308, 1.0269178704666575)
# 2    (0.4712234217757892, 0.49167296030558955)
# 3                                   (nan, nan)
# 4     (0.0403326102806191, 0.0576868059373771)
# 5   (0.07734390376505915, 0.10391013843138777)
# 6     (0.3428969810303428, 0.3625205098454321)
# 7     (0.5096461791599562, 0.5459585431861937)
# 8     (1.3894749397985229, 1.5222373933875049)
# 9      (2.129468278102574, 2.2631667397270414)
# 10     (4.578293147114306, 4.7548328357882506)
# 11      (48924001985.03187, 48933314303.46813)
# configDpt70
# ############################ Ville : configDpt70#####################
# 0070
# log-configDpt70-MT-0070configVaccinNumRepli1.txt
# Le taux de mort de cas connu est de : 2.0868113522537564%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.010624147412170173%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.7042253521126761%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.684931506849315%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.3157894736842104%
# Le taux de mortalité pour les 65 - 75 ans est de : 4.761904761904762%
# Le taux de mortalité pour les 75 + ans est de : 11.864406779661017%
# ############
# ################
#  replication = 0
# 0165
# log-configDpt70-MT-0165configVaccinNumRepli2.txt
# Le taux de mort de cas connu est de : 1.7781541066892466%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.008924283826222946%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.0%
# Le taux de mortalité pour les 45 - 55 ans est de : 2.73972602739726%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.2556390977443606%
# Le taux de mortalité pour les 65 - 75 ans est de : 2.8368794326241136%
# Le taux de mortalité pour les 75 + ans est de : 7.352941176470589%
# ############
# ################
#  replication = 1
# 0260
# log-configDpt70-MT-0260configVaccinNumRepli3.txt
# Le taux de mort de cas connu est de : 1.6295025728987993%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.008074352033249332%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.6493506493506493%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.6622516556291391%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.0%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.4388489208633095%
# Le taux de mortalité pour les 65 - 75 ans est de : 3.361344537815126%
# Le taux de mortalité pour les 75 + ans est de : 9.565217391304348%
# ############
# ################
#  replication = 2
# 0355
# log-configDpt70-MT-0355configVaccinNumRepli4.txt
# Le taux de mort de cas connu est de : 1.5789473684210527%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.007649386136762524%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.7246376811594203%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.6451612903225806%
# Le taux de mortalité pour les 55 - 65 ans est de : 3.3557046979865772%
# Le taux de mortalité pour les 65 - 75 ans est de : 3.2%
# Le taux de mortalité pour les 75 + ans est de : 7.142857142857142%
# ############
# ################
#  replication = 3
#                            Champs            R1            R2            R3  \
# 0            nbCasCovidConnuTotal  1.198000e+03  1.181000e+03  1.166000e+03
# 1              tauxDeMortCasConnu  2.086811e+00  1.778154e+00  1.629503e+00
# 2   tauxMortalitePopulationGobale  1.062415e-02  8.924284e-03  8.074352e-03
# 3               tauxDeMort0-15ans  0.000000e+00  0.000000e+00  0.000000e+00
# 4              tauxDeMort15-25ans  0.000000e+00  0.000000e+00  0.000000e+00
# 5              tauxDeMort25-35ans  0.000000e+00  0.000000e+00  6.493506e-01
# 6              tauxDeMort35-45ans  7.042254e-01  0.000000e+00  6.622517e-01
# 7              tauxDeMort45-55ans  6.849315e-01  2.739726e+00  0.000000e+00
# 8              tauxDeMort55-65ans  1.315789e+00  2.255639e+00  1.438849e+00
# 9              tauxDeMort65-75ans  4.761905e+00  2.836879e+00  3.361345e+00
# 10               tauxDeMort75+ans  1.186441e+01  7.352941e+00  9.565217e+00
# 11                 nbRandomGenere  4.918665e+10  4.918999e+10  4.919118e+10
#
#               R4       Moyenne      Variance  \
# 0   1.140000e+03  1.171250e+03  6.049167e+02
# 1   1.578947e+00  1.768354e+00  5.222191e-02
# 2   7.649386e-03  8.818042e-03  1.730712e-06
# 3   0.000000e+00  0.000000e+00  0.000000e+00
# 4   0.000000e+00  0.000000e+00  0.000000e+00
# 5   0.000000e+00  1.623377e-01  1.054141e-01
# 6   7.246377e-01  5.227787e-01  1.221401e-01
# 7   6.451613e-01  1.017455e+00  1.416869e+00
# 8   3.355705e+00  2.091496e+00  8.842785e-01
# 9   3.200000e+00  3.540032e+00  7.116492e-01
# 10  7.142857e+00  8.981356e+00  4.894896e+00
# 11  4.918486e+10  4.918817e+10  8.571319e+12
#
#                                   Intervalle95%
# 0      (1132.1137811068825, 1210.3862188931175)
# 1       (1.4047257399035866, 2.131981960227841)
# 2   (0.006724684548566737, 0.01091140015563575)
# 3                                    (nan, nan)
# 4                                    (nan, nan)
# 5     (-0.3542932313773154, 0.6789685560526401)
# 6    (-0.03333064537914254, 1.0788879898297603)
# 7     (-0.8766148363385333, 2.9115242486231114)
# 8       (0.5951716394831981, 3.587819455656031)
# 9         (2.1976874384811014, 4.8823769276909)
# 10      (5.460867887291434, 12.501843357855114)
# 11       (49183511181.53094, 49192828370.96906)
# configDpt71
# ############################ Ville : configDpt71#####################
# 0071
# log-configDpt71-MT-0071configVaccinNumRepli1.txt
# Le taux de mort de cas connu est de : 1.166407465007776%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.005439778927384391%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.5988023952095809%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.8620689655172413%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.023121387283237%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.8518518518518516%
# Le taux de mortalité pour les 75 + ans est de : 5.46218487394958%
# ############
# ################
#  replication = 0
# 0166
# log-configDpt71-MT-0166configVaccinNumRepli2.txt
# Le taux de mort de cas connu est de : 1.2769062385990515%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.0063464087486151234%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.6557377049180327%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.24630541871921183%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.6706231454005933%
# Le taux de mortalité pour les 65 - 75 ans est de : 2.622950819672131%
# Le taux de mortalité pour les 75 + ans est de : 5.681818181818182%
# ############
# ################
#  replication = 1
# 0261
# log-configDpt71-MT-0261configVaccinNumRepli3.txt
# Le taux de mort de cas connu est de : 1.4543339150668992%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.009066298212307318%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.24390243902439024%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.5194805194805194%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.8113590263691683%
# Le taux de mortalité pour les 55 - 65 ans est de : 2.159827213822894%
# Le taux de mortalité pour les 65 - 75 ans est de : 3.1914893617021276%
# Le taux de mortalité pour les 75 + ans est de : 6.25%
# ############
# ################
#  replication = 2
# 0356
# log-configDpt71-MT-0356configVaccinNumRepli4.txt
# /tmp/ipykernel_1522559/3049923515.py:360: DeprecationWarning: Use of keyword argument `alpha` for method `interval` is deprecated. Use first positional argument or keyword argument `confidence` instead.
#   listIntervalle95 = [st.t.interval(alpha=0.95, df=len(r)-1, loc=np.mean(r), scale=st.sem(r)) for r in zip(*listResReplicationTruncated)]
# /home/local.isima.fr/beantunes/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2343: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/local.isima.fr/beantunes/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2344: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# /tmp/ipykernel_1522559/3049923515.py:360: DeprecationWarning: Use of keyword argument `alpha` for method `interval` is deprecated. Use first positional argument or keyword argument `confidence` instead.
#   listIntervalle95 = [st.t.interval(alpha=0.95, df=len(r)-1, loc=np.mean(r), scale=st.sem(r)) for r in zip(*listResReplicationTruncated)]
# /home/local.isima.fr/beantunes/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2343: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/local.isima.fr/beantunes/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2344: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [5], line 182
#     113 """
#     114 plt.figure((listResReplication.index(replication)*6)+compteurFigure)
#     115 print("Courbe des nouveaux cas sur la réplication num : " +str(listResReplication.index(replication)))
#    (...)
#     179     write.writerow(listTauxIncidence)
#     180 """
#     181 nbMortTotal = sum(listNbNouvMort)
# --> 182 tauxDeMortCasConnu = (nbMortTotal / nbCasCovidConnuTotal) * 100
#     183 tauxMortalitePopulationGobale = (nbMortTotal / nbHumainSimuDepart) * 100
#     185 print("Le taux de mort de cas connu est de : " + str(tauxDeMortCasConnu) + "%")
#
# ZeroDivisionError: division by zero

# %%
import matplotlib.pyplot as plt
plt.plot([44,221,588,917,1990],[70000,161000,264000,330000,492000])

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

x = np.array([44,221,588,917,1990]).reshape(-1,1)
y = np.array([70000,161000,264000,330000,492000])

model = LinearRegression()
model.fit(np.log(x),y)

x_pred = np.array([50,100,220,500,1000,1500,3000,5000,8000,12000]).reshape(-1,1)
y_pred = model.predict(np.log(x_pred))
print(y_pred)

plt.plot([44,221,588,917,1990],[70000,161000,264000,330000,492000],color='r')
plt.plot([50,100,220,500,1000,1500,3000,5000,8000,12000],y_pred)
# Out:
# [ 43885.06248518 116924.96278337 200008.1067469  286518.35933351
#  359558.2596317  402283.86236256 475323.76266075 529151.65618184
#  578677.96052628 621403.56325713]
